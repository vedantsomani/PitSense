# %%
import pandas as pd 
df_ckts = pd.read_csv('Formula_1/circuits.csv')
df_ckts
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# ...

# %%
pip install jupyterthemes
# Out:
# ...
#      ---------------------------------------- 7.0/7.0 MB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 8.1/8.1 MB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 46.7/46.7 kB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 221.2/221.2 kB 2.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 71.9/71.9 kB 655.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.3/2.3 MB 3.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 111.1/111.1 kB 2.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 66.4/66.4 kB 1.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastf1
# Out:
# ...
#      ------------------------------------ 148.4/148.4 kB 885.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.4/61.4 kB 1.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.6/1.6 MB 1.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 159.1/159.1 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 41.3/41.3 MB 4.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 69.4/69.4 kB 3.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 63.8/63.8 kB 3.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 43.9/43.9 kB 2.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.6.3
#     Uninstalling typing_extensions-4.6.3:
#       Successfully uninstalled typing_extensions-4.6.3
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
# ...

# %%
import fastf1
from fastf1 import plotting 
from fastf1.core import Laps 
fastf1.Cache.enable_cache('f1_cache')

session = fastf1.get_session(2024, "British Grand Prix", 'R')
session.load()
laps = session.laps
print(laps.columns)
# Out:
# core           INFO 	Loading data for British Grand Prix - Race [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# ...

# %%
import pandas as pd 
import fastf1
from fastf1 import plotting 
from fastf1.core import Laps 
fastf1.Cache.enable_cache('f1_cache')

session = fastf1.get_session(2024, "British Grand Prix", 'R')
session.load()
laps = session.laps
print(laps.columns)
# Out:
# core           INFO 	Loading data for British Grand Prix - Race [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '1', '4', '81', '55', '27', '18', '14', '23', '22', '2', '20', '3', '16', '77', '31', '11', '24', '63', '10']
# ...

# %%
laps['Compound']
# Out:
# 0            MEDIUM
# 1            MEDIUM
# 2            MEDIUM
# 3            MEDIUM
# 4            MEDIUM
#            ...
# 956    INTERMEDIATE
# 957    INTERMEDIATE
# 958    INTERMEDIATE
# 959    INTERMEDIATE
# 960          MEDIUM
# Name: Compound, Length: 961, dtype: object

# %%
tyres_used = laps[['Time', 'Driver', 'DriverNumber', 'Stint', 'Compound', 'TyreLife', 'FreshTyre', 'Team']]
tyres_used
# Out:
#                       Time Driver DriverNumber  Stint      Compound  TyreLife  \
# 0   0 days 00:59:51.778000    HAM           44    1.0        MEDIUM       1.0
# 1   0 days 01:01:23.198000    HAM           44    1.0        MEDIUM       2.0
# 2   0 days 01:02:54.914000    HAM           44    1.0        MEDIUM       3.0
# 3   0 days 01:04:26.902000    HAM           44    1.0        MEDIUM       4.0
# 4   0 days 01:05:58.579000    HAM           44    1.0        MEDIUM       5.0
# ..                     ...    ...          ...    ...           ...       ...
# 956 0 days 01:45:56.213000    RUS           63    2.0  INTERMEDIATE       3.0
# 957 0 days 01:47:38.115000    RUS           63    2.0  INTERMEDIATE       4.0
# 958 0 days 01:49:21.200000    RUS           63    2.0  INTERMEDIATE       5.0
# 959 0 days 01:51:07.421000    RUS           63    2.0  INTERMEDIATE       6.0
# 960 0 days 00:59:50.955000    GAS           10    1.0        MEDIUM       1.0
#
#      FreshTyre      Team
# ...

# %%
tyres_used.head(10)
# Out:
#                     Time Driver DriverNumber  Stint Compound  TyreLife  \
# 0 0 days 00:59:51.778000    HAM           44    1.0   MEDIUM       1.0
# 1 0 days 01:01:23.198000    HAM           44    1.0   MEDIUM       2.0
# 2 0 days 01:02:54.914000    HAM           44    1.0   MEDIUM       3.0
# 3 0 days 01:04:26.902000    HAM           44    1.0   MEDIUM       4.0
# 4 0 days 01:05:58.579000    HAM           44    1.0   MEDIUM       5.0
# 5 0 days 01:07:30.325000    HAM           44    1.0   MEDIUM       6.0
# 6        0 days 01:09:02    HAM           44    1.0   MEDIUM       7.0
# 7 0 days 01:10:33.760000    HAM           44    1.0   MEDIUM       8.0
# 8 0 days 01:12:05.324000    HAM           44    1.0   MEDIUM       9.0
# 9 0 days 01:13:36.839000    HAM           44    1.0   MEDIUM      10.0
#
#    FreshTyre      Team
# 0       True  Mercedes
# 1       True  Mercedes
# 2       True  Mercedes
# 3       True  Mercedes
# 4       True  Mercedes
# 5       True  Mercedes
# ...

# %%
tyres_used[tyres_used['Driver'] == "HAM"]
# Out:
#                      Time Driver DriverNumber  Stint      Compound  TyreLife  \
# 0  0 days 00:59:51.778000    HAM           44    1.0        MEDIUM       1.0
# 1  0 days 01:01:23.198000    HAM           44    1.0        MEDIUM       2.0
# 2  0 days 01:02:54.914000    HAM           44    1.0        MEDIUM       3.0
# 3  0 days 01:04:26.902000    HAM           44    1.0        MEDIUM       4.0
# 4  0 days 01:05:58.579000    HAM           44    1.0        MEDIUM       5.0
# 5  0 days 01:07:30.325000    HAM           44    1.0        MEDIUM       6.0
# 6         0 days 01:09:02    HAM           44    1.0        MEDIUM       7.0
# 7  0 days 01:10:33.760000    HAM           44    1.0        MEDIUM       8.0
# 8  0 days 01:12:05.324000    HAM           44    1.0        MEDIUM       9.0
# 9  0 days 01:13:36.839000    HAM           44    1.0        MEDIUM      10.0
# 10 0 days 01:15:08.326000    HAM           44    1.0        MEDIUM      11.0
# ...

# %%
import pandas as pd 
import fastf1
from fastf1 import plotting 
from fastf1.core import Laps 
fastf1.Cache.enable_cache('f1_cache')

session = fastf1.get_session(2024, "British Grand Prix", 'R')
session.load()
laps = session.laps
print(laps.columns)
# Out:
# core           INFO 	Loading data for British Grand Prix - Race [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '1', '4', '81', '55', '27', '18', '14', '23', '22', '2', '20', '3', '16', '77', '31', '11', '24', '63', '10']
# ...

# %%
df_laps = laps[['Time', 'Driver', 'DriverNumber', 'Stint', 'Compound', 'TyreLife', 'FreshTyre', 'Team']]
df_laps
# Out:
#                       Time Driver DriverNumber  Stint      Compound  TyreLife  \
# 0   0 days 00:59:51.778000    HAM           44    1.0        MEDIUM       1.0
# 1   0 days 01:01:23.198000    HAM           44    1.0        MEDIUM       2.0
# 2   0 days 01:02:54.914000    HAM           44    1.0        MEDIUM       3.0
# 3   0 days 01:04:26.902000    HAM           44    1.0        MEDIUM       4.0
# 4   0 days 01:05:58.579000    HAM           44    1.0        MEDIUM       5.0
# ..                     ...    ...          ...    ...           ...       ...
# 956 0 days 01:45:56.213000    RUS           63    2.0  INTERMEDIATE       3.0
# 957 0 days 01:47:38.115000    RUS           63    2.0  INTERMEDIATE       4.0
# 958 0 days 01:49:21.200000    RUS           63    2.0  INTERMEDIATE       5.0
# 959 0 days 01:51:07.421000    RUS           63    2.0  INTERMEDIATE       6.0
# 960 0 days 00:59:50.955000    GAS           10    1.0        MEDIUM       1.0
#
#      FreshTyre      Team
# ...

# %%
# Group by Driver, Stint, Compound, FreshTyre
strategy_df = laps.groupby(['Driver', 'Stint', 'Compound', 'FreshTyre']) \
                  .size().reset_index(name='StintLength')

# Sort for readability
strategy_df = strategy_df.sort_values(by=['Driver', 'Stint'])
print(strategy_df)
# Out:
#    Driver  Stint      Compound  FreshTyre  StintLength
# 0     ALB    1.0        MEDIUM       True           27
# 1     ALB    2.0  INTERMEDIATE       True           11
# 2     ALB    3.0        MEDIUM       True           14
# 3     ALO    1.0        MEDIUM       True           27
# 4     ALO    2.0  INTERMEDIATE       True           11
# ..    ...    ...           ...        ...          ...
# 60    ZHO    1.0          SOFT       True           12
# 61    ZHO    2.0        MEDIUM       True            7
# 62    ZHO    3.0  INTERMEDIATE       True            7
# 63    ZHO    4.0  INTERMEDIATE       True           11
# 64    ZHO    5.0          SOFT      False           13
#
# [65 rows x 5 columns]

# %%
strategy_df[strategy_df['Driver'] == 'VER']
# Out:
#    Driver  Stint      Compound  FreshTyre  StintLength
# 57    VER    1.0        MEDIUM       True           26
# 58    VER    2.0  INTERMEDIATE       True           12
# 59    VER    3.0          HARD       True           14

# %%
import matplotlib.pyplot as plt

driver = 'VER'  # Replace with any driver code

driver_laps = laps[laps['Driver'] == driver]

plt.figure(figsize=(12, 4))
plt.plot(driver_laps['LapNumber'], driver_laps['Compound'], marker='o', linestyle='-')
plt.title(f'{driver} Tyre Compounds per Lap - British GP 2024')
plt.xlabel('Lap Number')
plt.ylabel('Compound')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Use 1 row per stint
stint_data = laps.groupby(['Driver', 'Stint']).agg({
    'Compound': 'first',
    'LapNumber': ['min', 'max']
}).reset_index()

stint_data.columns = ['Driver', 'Stint', 'Compound', 'StartLap', 'EndLap']
stint_data['StintLength'] = stint_data['EndLap'] - stint_data['StartLap'] + 1

plt.figure(figsize=(12, 8))

for i, row in stint_data.iterrows():
    plt.barh(
        y=row['Driver'],
        width=row['StintLength'],
        left=row['StartLap'],
        label=row['Compound'],
        color={'SOFT': 'red', 'MEDIUM': 'yellow', 'HARD': 'white'}.get(row['Compound'], 'gray'),
        edgecolor='black'
    )

plt.xlabel('Lap Number')
plt.ylabel('Driver')
plt.title('Tyre Strategies by Driver (British GP 2024)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import seaborn as sns
#       3 # Use 1 row per stint
#       4 stint_data = laps.groupby(['Driver', 'Stint']).agg({
#       5     'Compound': 'first',
#       6     'LapNumber': ['min', 'max']
#       7 }).reset_index()
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install seaborn
# Out:
# ...
#      -------------------------------------- 294.9/294.9 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns

# Use 1 row per stint
stint_data = laps.groupby(['Driver', 'Stint']).agg({
    'Compound': 'first',
    'LapNumber': ['min', 'max']
}).reset_index()

stint_data.columns = ['Driver', 'Stint', 'Compound', 'StartLap', 'EndLap']
stint_data['StintLength'] = stint_data['EndLap'] - stint_data['StartLap'] + 1

plt.figure(figsize=(12, 8))

for i, row in stint_data.iterrows():
    plt.barh(
        y=row['Driver'],
        width=row['StintLength'],
        left=row['StartLap'],
        label=row['Compound'],
        color={'SOFT': 'red', 'MEDIUM': 'yellow', 'HARD': 'white'}.get(row['Compound'], 'gray'),
        edgecolor='black'
    )

plt.xlabel('Lap Number')
plt.ylabel('Driver')
plt.title('Tyre Strategies by Driver (British GP 2024)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 import seaborn as sns
#       3 # Use 1 row per stint
# ----> 4 stint_data = laps.groupby(['Driver', 'Stint']).agg({
#       5     'Compound': 'first',
#       6     'LapNumber': ['min', 'max']
#       7 }).reset_index()
#       9 stint_data.columns = ['Driver', 'Stint', 'Compound', 'StartLap', 'EndLap']
#      10 stint_data['StintLength'] = stint_data['EndLap'] - stint_data['StartLap'] + 1
#
# NameError: name 'laps' is not defined

# %%
import os
import pandas as pd
import numpy as np
import fastf1
fastf1.logger.set_log_level('INFO')
# Create cache once
os.makedirs("f1_cache", exist_ok=True)
fastf1.Cache.enable_cache("f1_cache")
def load_clean_laps(year: int, event: str, session_code: str = 'R'):
    """
    Returns a cleaned lap-level DataFrame for a race with core features engineered.
    """
    ses = fastf1.get_session(year, event, session_code)
    ses.load()  # needs internet on first run; then uses cache

    laps = ses.laps.copy()

    # --- Basic cleaning
    # Exclude inaccurate or deleted laps
    laps = laps[(laps["IsAccurate"] == True) & (laps["Deleted"] == False)]

    # Exclude in-laps and out-laps
    laps = laps[laps["PitInTime"].isna() & laps["PitOutTime"].isna()]

    # Exclude SC/VSC/Yellow laps -> keep 'green' only.
    # TrackStatus can be NaN (treat as green) or codes like '1' (= green).
    def is_green(x):
        if pd.isna(x): 
            return True
        # Some laps have multiple codes like '1;2'; keep strictly green-only laps
        return str(x).strip() == '1'
    laps = laps[laps["TrackStatus"].apply(is_green)]

    # Drop wet compounds initially (start with dry model; add later)
    laps = laps[~laps["Compound"].isin(["INTERMEDIATE", "WET"])]

    # --- Feature engineering
    # Timedelta -> seconds
    laps["LapTime_s"] = laps["LapTime"].dt.total_seconds()

    # Tyre age (already there as TyreLife, but ensure numeric)
    laps["TyreAge"] = laps["TyreLife"].astype(float)

    # Stint-relative lap index (helps model degradation within stint)
    laps["StintLap"] = laps.groupby(["Driver", "Stint"])["LapNumber"] \
                           .rank(method="first").astype(int)

    # Driver pace normalization options (pick later in modeling)
    # 1) Delta to each driver's race median
    laps["DeltaToDriverMedian_s"] = laps["LapTime_s"] - laps.groupby("Driver")["LapTime_s"].transform("median")
    # 2) Delta to each driver's best (more aggressive)
    laps["DeltaToDriverBest_s"] = laps["LapTime_s"] - laps.groupby("Driver")["LapTime_s"].transform("min")

    # Rolling form (last 3 laps average) within stint
    laps["StintRoll3_s"] = laps.sort_values(["Driver","Stint","LapNumber"]) \
        .groupby(["Driver","Stint"])["LapTime_s"].transform(lambda s: s.rolling(3, min_periods=1).mean())

    # One-hot encode compound (or leave as category for tree models)
    laps["Compound"] = laps["Compound"].astype("category")

    # Merge weather (nearest time to lap start)
    wthr = ses.weather_data  # columns: Time, AirTemp, Humidity, Pressure, Rainfall, TrackTemp, WindDirection, WindSpeed
    # align by nearest lap start time
    laps = pd.merge_asof(
        laps.sort_values("LapStartTime"),
        wthr.sort_values("Time").rename(columns={"Time":"WeatherTime"}),
        left_on="LapStartTime", right_on="WeatherTime", direction="nearest"
    )

    # Keep only the columns we’ll need downstream (you can add more later)
    cols = [
        "Driver","Team","LapNumber","Stint","StintLap","Compound","TyreAge",
        "FreshTyre","LapTime_s","DeltaToDriverMedian_s","DeltaToDriverBest_s",
        "TrackTemp","AirTemp","Humidity","WindSpeed","WindDirection","Pressure","Rainfall",
        "Position"
    ]
    return laps[cols].reset_index(drop=True)

# %%
print("Lights Out and away we go!")
# Out:
# Lights Out and away we go!

# %%
import fastf1

# Enable cache (will create folder if it doesn't exist)
fastf1.Cache.enable_cache('f1_cache')

# Show progress logs (so you see downloads happening)
fastf1.logger.set_log_level('INFO')

# Load a small session first (Free Practice 1 = FP1)
session = fastf1.get_session(2024, "British Grand Prix", 'FP1')
print("Loading session...")
session.load()
print("Session loaded successfully!")

# Extract laps
laps = session.laps

# Show first 5 rows
print("Here are the first few laps:")
print(laps.head())
# Out:
# core           INFO 	Loading data for British Grand Prix - Practice 1 [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# Loading session...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# ...

# %%
print(laps.columns)
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
races_2023 = fastf1.get_event_schedule(2023)
print(races_2023[['RoundNumber', 'Country', 'EventDate', 'EventName']])
# Out:
#     RoundNumber        Country  EventDate                 EventName
# 0             0        Bahrain 2023-02-25        Pre-Season Testing
# 1             1        Bahrain 2023-03-05        Bahrain Grand Prix
# 2             2   Saudi Arabia 2023-03-19  Saudi Arabian Grand Prix
# 3             3      Australia 2023-04-02     Australian Grand Prix
# 4             4     Azerbaijan 2023-04-30     Azerbaijan Grand Prix
# 5             5  United States 2023-05-07          Miami Grand Prix
# 6             6         Monaco 2023-05-28         Monaco Grand Prix
# 7             7          Spain 2023-06-04        Spanish Grand Prix
# 8             8         Canada 2023-06-18       Canadian Grand Prix
# 9             9        Austria 2023-07-02       Austrian Grand Prix
# 10           10  Great Britain 2023-07-09        British Grand Prix
# 11           11        Hungary 2023-07-23      Hungarian Grand Prix
# 12           12        Belgium 2023-07-30        Belgian Grand Prix
# ...

# %%
import pandas as pd 
df_races = pd.DataFrame(races_2023)
df_races
# Out:
#     RoundNumber        Country           Location  \
# 0             0        Bahrain             Sakhir
# 1             1        Bahrain             Sakhir
# 2             2   Saudi Arabia             Jeddah
# 3             3      Australia          Melbourne
# 4             4     Azerbaijan               Baku
# 5             5  United States              Miami
# 6             6         Monaco             Monaco
# 7             7          Spain          Barcelona
# 8             8         Canada           Montréal
# 9             9        Austria          Spielberg
# 10           10  Great Britain        Silverstone
# 11           11        Hungary           Budapest
# 12           12        Belgium  Spa-Francorchamps
# 13           13    Netherlands          Zandvoort
# 14           14          Italy              Monza
# 15           15      Singapore         Marina Bay
# 16           16          Japan             Suzuka
# 17           17          Qatar             Lusail
# ...

# %%
import fastf1
import pandas as pd

# Enable cache
fastf1.Cache.enable_cache('f1_cache')

# Get the full schedule of 2023
schedule = fastf1.get_event_schedule(2023)

# Empty list to collect data
all_races_data = []

# Loop through all races
for _, event in schedule.iterrows():
    gp_name = event["EventName"]
    print(f"Loading {gp_name} ...")

    try:
        # Load the race session
        session = fastf1.get_session(2023, gp_name, 'R')
        session.load()

        # Get lap data
        laps = session.laps

        # Select only useful columns
        useful_cols = [
            'Time', 'Driver', 'DriverNumber', 'LapNumber', 'Stint',
            'Compound', 'TyreLife', 'FreshTyre', 'LapTime',
            'Sector1Time', 'Sector2Time', 'Sector3Time',
            'Team', 'Position'
        ]
        race_data = laps[useful_cols].copy()
        race_data["GP"] = gp_name   # add column for race name

        # Append to list
        all_races_data.append(race_data)

    except Exception as e:
        print(f"Could not load {gp_name}: {e}")

# Combine all races into one DataFrame
all_laps_2023 = pd.concat(all_races_data, ignore_index=True)

# Save as CSV if you want
all_laps_2023.to_csv("f1_2023_lapdata.csv", index=False)

all_laps_2023.head()
# Out:
# events      WARNING 	Correcting user input 'Pre-Season Testing' to 'British Grand Prix'
# core           INFO 	Loading data for British Grand Prix - Race [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Loading Pre-Season Testing ...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# ...

# %%
all_laps_2023[(all_laps_2023['GP'] == 'British Grand Prix') & (all_laps_2023['Driver'] == 'VER')]
# Out:
#                         Time Driver DriverNumber  LapNumber  Stint Compound  \
# 11571 0 days 01:03:46.121000    VER            1        1.0    1.0   MEDIUM
# 11572 0 days 01:05:19.554000    VER            1        2.0    1.0   MEDIUM
# 11573 0 days 01:06:52.284000    VER            1        3.0    1.0   MEDIUM
# 11574 0 days 01:08:25.064000    VER            1        4.0    1.0   MEDIUM
# 11575 0 days 01:09:57.646000    VER            1        5.0    1.0   MEDIUM
# 11576 0 days 01:11:30.673000    VER            1        6.0    1.0   MEDIUM
# 11577 0 days 01:13:03.773000    VER            1        7.0    1.0   MEDIUM
# 11578 0 days 01:14:36.657000    VER            1        8.0    1.0   MEDIUM
# 11579 0 days 01:16:09.479000    VER            1        9.0    1.0   MEDIUM
# 11580 0 days 01:17:42.073000    VER            1       10.0    1.0   MEDIUM
# 11581 0 days 01:19:14.670000    VER            1       11.0    1.0   MEDIUM
# ...

# %%
all_laps_2023.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
#        'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time',
#        'Sector3Time', 'Team', 'Position', 'GP'],
#       dtype='object')

# %%
import pandas as pd
import fastf1
fastf1.Cache.enable_cache('f1_cache')
all_laps_2023.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 import fastf1
#       3 fastf1.Cache.enable_cache('f1_cache')
# ----> 4 all_laps_2023.head(5)
#
# NameError: name 'all_laps_2023' is not defined

# %%
import fastf1
import pandas as pd

# Enable cache
fastf1.Cache.enable_cache('f1_cache')

# Get the full schedule of 2023
schedule = fastf1.get_event_schedule(2023)

# Empty list to collect data
all_races_data = []

# Loop through all races
for _, event in schedule.iterrows():
    gp_name = event["EventName"]
    print(f"Loading {gp_name} ...")

    try:
        # Load the race session
        session = fastf1.get_session(2023, gp_name, 'R')
        session.load()

        # Get lap data
        laps = session.laps

        # Select only useful columns
        useful_cols = [
            'Time', 'Driver', 'DriverNumber', 'LapNumber', 'Stint',
            'Compound', 'TyreLife', 'FreshTyre', 'LapTime',
            'Sector1Time', 'Sector2Time', 'Sector3Time',
            'Team', 'Position'
        ]
        race_data = laps[useful_cols].copy()
        race_data["GP"] = gp_name   # add column for race name

        # Append to list
        all_races_data.append(race_data)

    except Exception as e:
        print(f"Could not load {gp_name}: {e}")

# Combine all races into one DataFrame
all_laps_2023 = pd.concat(all_races_data, ignore_index=True)

# Save as CSV if you want
all_laps_2023.to_csv("f1_2023_lapdata.csv", index=False)

all_laps_2023.head()
# Out:
# events      WARNING 	Correcting user input 'Pre-Season Testing' to 'British Grand Prix'
# core           INFO 	Loading data for British Grand Prix - Race [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Loading Pre-Season Testing ...
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
import pandas as pd 
import numpy as np
import fastf1
fastf1.Cache.enable_cache('f1_cache')
race_23 = pd.read_csv("f1_2023_lapdata.csv")
race_23.head(5)
# Out:
#                      Time Driver  DriverNumber  LapNumber  Stint Compound  \
# 0  0 days 01:03:46.121000    VER             1        1.0    1.0   MEDIUM
# 1  0 days 01:05:19.554000    VER             1        2.0    1.0   MEDIUM
# 2  0 days 01:06:52.284000    VER             1        3.0    1.0   MEDIUM
# 3  0 days 01:08:25.064000    VER             1        4.0    1.0   MEDIUM
# 4  0 days 01:09:57.646000    VER             1        5.0    1.0   MEDIUM
#
#    TyreLife  FreshTyre                 LapTime             Sector1Time  \
# 0       1.0       True  0 days 00:01:37.167000                     NaN
# 1       2.0       True  0 days 00:01:33.433000  0 days 00:00:29.616000
# 2       3.0       True  0 days 00:01:32.730000  0 days 00:00:29.380000
# 3       4.0       True  0 days 00:01:32.780000  0 days 00:00:29.407000
# 4       5.0       True  0 days 00:01:32.582000  0 days 00:00:29.338000
#
#               Sector2Time             Sector3Time             Team  Position  \
# ...

# %%
race_23[race_23['GP'] == 'Bahrain Grand Prix']
# Out:
#                         Time Driver  DriverNumber  LapNumber  Stint Compound  \
# 971   0 days 01:04:15.902000    VER             1        1.0    1.0     SOFT
# 972   0 days 01:05:53.876000    VER             1        2.0    1.0     SOFT
# 973   0 days 01:07:31.882000    VER             1        3.0    1.0     SOFT
# 974   0 days 01:09:09.858000    VER             1        4.0    1.0     SOFT
# 975   0 days 01:10:47.893000    VER             1        5.0    1.0     SOFT
# ...                      ...    ...           ...        ...    ...      ...
# 2022  0 days 01:17:53.305000    PIA            81        9.0    1.0     SOFT
# 2023  0 days 01:19:34.889000    PIA            81       10.0    1.0     SOFT
# 2024  0 days 01:21:16.241000    PIA            81       11.0    1.0     SOFT
# 2025  0 days 01:22:57.397000    PIA            81       12.0    1.0     SOFT
# 2026  0 days 01:24:59.468000    PIA            81       13.0    1.0     SOFT
#
# ...

# %%
race_23[race_23['GP'] == 'Pre-Season Testing']
# Out:
#                        Time Driver  DriverNumber  LapNumber  Stint Compound  \
# 0    0 days 01:03:46.121000    VER             1        1.0    1.0   MEDIUM
# 1    0 days 01:05:19.554000    VER             1        2.0    1.0   MEDIUM
# 2    0 days 01:06:52.284000    VER             1        3.0    1.0   MEDIUM
# 3    0 days 01:08:25.064000    VER             1        4.0    1.0   MEDIUM
# 4    0 days 01:09:57.646000    VER             1        5.0    1.0   MEDIUM
# ..                      ...    ...           ...        ...    ...      ...
# 966  0 days 02:21:28.248000    PIA            81       48.0    2.0     HARD
# 967  0 days 02:22:59.670000    PIA            81       49.0    2.0     HARD
# 968  0 days 02:24:31.422000    PIA            81       50.0    2.0     HARD
# 969  0 days 02:26:02.727000    PIA            81       51.0    2.0     HARD
# 970  0 days 02:27:33.668000    PIA            81       52.0    2.0     HARD
#
# ...

# %%
race_23.isnull()
# Out:
#         Time  Driver  DriverNumber  LapNumber  Stint  Compound  TyreLife  \
# 0      False   False         False      False  False     False     False
# 1      False   False         False      False  False     False     False
# 2      False   False         False      False  False     False     False
# 3      False   False         False      False  False     False     False
# 4      False   False         False      False  False     False     False
# ...      ...     ...           ...        ...    ...       ...       ...
# 25388  False   False         False      False  False     False     False
# 25389  False   False         False      False  False     False     False
# 25390  False   False         False      False  False     False     False
# 25391  False   False         False      False  False     False     False
# 25392  False   False         False      False  False     False     False
#
#        FreshTyre  LapTime  Sector1Time  Sector2Time  Sector3Time   Team  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

def clean_f1_data(df):
    print("🔎 Initial data shape:", df.shape)

    # 1. Keep only needed columns
    keep_cols = ['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
                 'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time',
                 'Sector3Time', 'Team', 'Position', 'GP']
    df = df[keep_cols]
    print("✅ Kept important columns:", keep_cols)

    # 2. Convert LapTime + Sectors to seconds
    for col in ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']:
        df[col] = df[col].dt.total_seconds()
    print("✅ Converted LapTime & Sector times to seconds")

    # 3. Handle missing values
    before_drop = df.shape[0]
    df = df.dropna(subset=['LapTime', 'Compound'])  # drop useless laps
    after_drop = df.shape[0]
    print(f"🗑️ Dropped {before_drop - after_drop} rows with missing LapTime/Compound")

    missing_tyre = df['TyreLife'].isna().sum()
    df['TyreLife'] = df['TyreLife'].fillna(0).astype(int)
    print(f"🛠️ Filled {missing_tyre} missing TyreLife values with 0")

    missing_fresh = df['FreshTyre'].isna().sum()
    df['FreshTyre'] = df['FreshTyre'].fillna(False)
    print(f"🛠️ Filled {missing_fresh} missing FreshTyre values with False")

    # 4. Remove outlier laps (very slow laps)
    median_lap = df['LapTime'].median()
    before_outlier = df.shape[0]
    df = df[df['LapTime'] < 1.5 * median_lap]
    after_outlier = df.shape[0]
    print(f"⚡ Removed {before_outlier - after_outlier} outlier laps (>1.5x median lap time)")

    # 5. Normalize numeric features
    scaler = MinMaxScaler()
    num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife']
    df[num_cols] = scaler.fit_transform(df[num_cols])
    print(f"📊 Normalized numeric columns: {num_cols}")

    # 6. Reset index
    df = df.reset_index(drop=True)
    print("✅ Final data shape after cleaning:", df.shape)

    # 7. Summary Report
    print("\n📋 --- Dataset Summary ---")
    print("Unique Drivers:", df['Driver'].nunique())
    print("Unique Teams:", df['Team'].nunique())
    print("Tyre Compounds used:", df['Compound'].unique().tolist())
    print("LapTime (scaled) min:", df['LapTime'].min(), "| max:", df['LapTime'].max())
    print("TyreLife (scaled) min:", df['TyreLife'].min(), "| max:", df['TyreLife'].max())
    print("-------------------------\n")

    return df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.preprocessing import MinMaxScaler
#       4 def clean_f1_data(df):
#       5     print("🔎 Initial data shape:", df.shape)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 8.9/8.9 MB 3.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 307.7/307.7 kB 2.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

def clean_f1_data(df):
    print("🔎 Initial data shape:", df.shape)

    # 1. Keep only needed columns
    keep_cols = ['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
                 'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time',
                 'Sector3Time', 'Team', 'Position', 'GP']
    df = df[keep_cols]
    print("✅ Kept important columns:", keep_cols)

    # 2. Convert LapTime + Sectors to seconds
    for col in ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']:
        df[col] = df[col].dt.total_seconds()
    print("✅ Converted LapTime & Sector times to seconds")

    # 3. Handle missing values
    before_drop = df.shape[0]
    df = df.dropna(subset=['LapTime', 'Compound'])  # drop useless laps
    after_drop = df.shape[0]
    print(f"🗑️ Dropped {before_drop - after_drop} rows with missing LapTime/Compound")

    missing_tyre = df['TyreLife'].isna().sum()
    df['TyreLife'] = df['TyreLife'].fillna(0).astype(int)
    print(f"🛠️ Filled {missing_tyre} missing TyreLife values with 0")

    missing_fresh = df['FreshTyre'].isna().sum()
    df['FreshTyre'] = df['FreshTyre'].fillna(False)
    print(f"🛠️ Filled {missing_fresh} missing FreshTyre values with False")

    # 4. Remove outlier laps (very slow laps)
    median_lap = df['LapTime'].median()
    before_outlier = df.shape[0]
    df = df[df['LapTime'] < 1.5 * median_lap]
    after_outlier = df.shape[0]
    print(f"⚡ Removed {before_outlier - after_outlier} outlier laps (>1.5x median lap time)")

    # 5. Normalize numeric features
    scaler = MinMaxScaler()
    num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife']
    df[num_cols] = scaler.fit_transform(df[num_cols])
    print(f"📊 Normalized numeric columns: {num_cols}")

    # 6. Reset index
    df = df.reset_index(drop=True)
    print("✅ Final data shape after cleaning:", df.shape)

    # 7. Summary Report
    print("\n📋 --- Dataset Summary ---")
    print("Unique Drivers:", df['Driver'].nunique())
    print("Unique Teams:", df['Team'].nunique())
    print("Tyre Compounds used:", df['Compound'].unique().tolist())
    print("LapTime (scaled) min:", df['LapTime'].min(), "| max:", df['LapTime'].max())
    print("TyreLife (scaled) min:", df['TyreLife'].min(), "| max:", df['TyreLife'].max())
    print("-------------------------\n")

    return df

# %%
race_2023.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 race_2023.head()
#
# NameError: name 'race_2023' is not defined

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

def time_to_seconds(x):
    """Convert 'M:SS.mmm' or 'SS.mmm' to seconds (float)."""
    if pd.isna(x):
        return None
    try:
        # If format is like "1:32.456"
        if ":" in str(x):
            minutes, sec = str(x).split(":")
            return int(minutes) * 60 + float(sec)
        return float(x)  # already in seconds
    except:
        return None

def clean_f1_data(df):
    print("🔎 Initial data shape:", df.shape)

    keep_cols = ['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
                 'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time',
                 'Sector3Time', 'Team', 'Position', 'GP']
    df = df[keep_cols]
    print("✅ Kept important columns:", keep_cols)

    # Convert LapTime + Sectors to seconds
    for col in ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']:
        df[col] = df[col].apply(time_to_seconds)
    print("✅ Converted LapTime & Sector times to seconds")

    # Handle missing values
    before_drop = df.shape[0]
    df = df.dropna(subset=['LapTime', 'Compound'])
    after_drop = df.shape[0]
    print(f"🗑️ Dropped {before_drop - after_drop} rows with missing LapTime/Compound")

    missing_tyre = df['TyreLife'].isna().sum()
    df['TyreLife'] = df['TyreLife'].fillna(0).astype(int)
    print(f"🛠️ Filled {missing_tyre} missing TyreLife values with 0")

    missing_fresh = df['FreshTyre'].isna().sum()
    df['FreshTyre'] = df['FreshTyre'].fillna(False)
    print(f"🛠️ Filled {missing_fresh} missing FreshTyre values with False")

    # Remove outliers
    median_lap = df['LapTime'].median()
    before_outlier = df.shape[0]
    df = df[df['LapTime'] < 1.5 * median_lap]
    after_outlier = df.shape[0]
    print(f"⚡ Removed {before_outlier - after_outlier} outlier laps (>1.5x median lap time)")

    # Normalize numeric features
    scaler = MinMaxScaler()
    num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife']
    df[num_cols] = scaler.fit_transform(df[num_cols])
    print(f"📊 Normalized numeric columns: {num_cols}")

    df = df.reset_index(drop=True)
    print("✅ Final data shape after cleaning:", df.shape)

    # Summary
    print("\n📋 --- Dataset Summary ---")
    print("Unique Drivers:", df['Driver'].nunique())
    print("Unique Teams:", df['Team'].nunique())
    print("Tyre Compounds used:", df['Compound'].unique().tolist())
    print("LapTime (scaled) min:", df['LapTime'].min(), "| max:", df['LapTime'].max())
    print("TyreLife (scaled) min:", df['TyreLife'].min(), "| max:", df['TyreLife'].max())
    print("-------------------------\n")

    return df

cleaned_df = clean_f1_data(df)
# Out:
# 🔎 Initial data shape: (25393, 15)
# ✅ Kept important columns: ['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound', 'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'Team', 'Position', 'GP']
# ✅ Converted LapTime & Sector times to seconds
# C:\Users\VANSH\AppData\Local\Temp\ipykernel_17664\2923608214.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(time_to_seconds)
# C:\Users\VANSH\AppData\Local\Temp\ipykernel_17664\2923608214.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.head(5)
# Out:
#                      Time Driver  DriverNumber  LapNumber  Stint Compound  \
# 0  0 days 01:03:46.121000    VER             1        1.0    1.0   MEDIUM
# 1  0 days 01:05:19.554000    VER             1        2.0    1.0   MEDIUM
# 2  0 days 01:06:52.284000    VER             1        3.0    1.0   MEDIUM
# 3  0 days 01:08:25.064000    VER             1        4.0    1.0   MEDIUM
# 4  0 days 01:09:57.646000    VER             1        5.0    1.0   MEDIUM
#
#    TyreLife  FreshTyre                 LapTime             Sector1Time  \
# 0       1.0       True  0 days 00:01:37.167000                     NaN
# 1       2.0       True  0 days 00:01:33.433000  0 days 00:00:29.616000
# 2       3.0       True  0 days 00:01:32.730000  0 days 00:00:29.380000
# 3       4.0       True  0 days 00:01:32.780000  0 days 00:00:29.407000
# 4       5.0       True  0 days 00:01:32.582000  0 days 00:00:29.338000
#
#               Sector2Time             Sector3Time             Team  Position  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

def clean_f1_data(df):
    print("🚦 Starting cleaning process...")

    # 1. Drop duplicate rows
    before = len(df)
    df = df.drop_duplicates()
    print(f"🧹 Removed duplicates: {before - len(df)} rows")

    # 2. Handle missing values
    missing_before = df.isna().sum().sum()
    df = df.dropna(subset=['Driver', 'Team'])   # critical info
    df = df.fillna({
        'TyreLife': 0,
        'Stint': -1
    })
    print(f"❓ Filled/Dropped missing values: {missing_before} → {df.isna().sum().sum()} remaining")

    # 3. Normalize numerical values
    num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife']
    available_cols = [col for col in num_cols if col in df.columns]

    if len(df[available_cols].dropna()) > 0:  # check if non-empty
        scaler = MinMaxScaler()
        df[available_cols] = scaler.fit_transform(df[available_cols])
        print(f"📊 Normalized numeric columns: {available_cols}")
    else:
        print("⚠️ Skipped normalization (no valid numeric data found)")

    # 4. Reset index
    df = df.reset_index(drop=True)
    print("🔄 Reset index")

    print("✅ Cleaning complete")
    print("-------------------------\n")

    return df
cleaned_df = clean_f1_data(df)
# Out:
# 🚦 Starting cleaning process...
# 🧹 Removed duplicates: 0 rows
# ❓ Filled/Dropped missing values: 1261 → 1226 remaining
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 39
#      36     print("-------------------------\n")
#      38     return df
# ---> 39 cleaned_df = clean_f1_data(df)
#
# Cell In[12], line 26, in clean_f1_data(df)
#      24 if len(df[available_cols].dropna()) > 0:  # check if non-empty
#      25     scaler = MinMaxScaler()
# ---> 26     df[available_cols] = scaler.fit_transform(df[available_cols])
#      27     print(f"📊 Normalized numeric columns: {available_cols}")
#      28 else:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

def clean_f1_data(df):
    print("🚦 Starting cleaning process...")

    # 1. Drop duplicate rows
    before = len(df)
    df = df.drop_duplicates()
    print(f"🧹 Removed duplicates: {before - len(df)} rows")

    # 2. Handle missing values
    missing_before = df.isna().sum().sum()
    df = df.dropna(subset=['Driver', 'Team'])   # critical info
    df = df.fillna({
        'TyreLife': 0,
        'Stint': -1
    })
    print(f"❓ Filled/Dropped missing values: {missing_before} → {df.isna().sum().sum()} remaining")

    # 3. Convert lap/sector times → seconds
    time_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']
    for col in time_cols:
        if col in df.columns:
            try:
                df[col] = pd.to_timedelta(df[col]).dt.total_seconds()
                print(f"⏱️ Converted {col} → seconds")
            except Exception as e:
                print(f"⚠️ Could not convert {col}: {e}")

    # 4. Normalize numerical values
    num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife']
    available_cols = [col for col in num_cols if col in df.columns]

    if len(df[available_cols].dropna()) > 0:  # check if non-empty
        scaler = MinMaxScaler()
        df[available_cols] = scaler.fit_transform(df[available_cols])
        print(f"📊 Normalized numeric columns: {available_cols}")
    else:
        print("⚠️ Skipped normalization (no valid numeric data found)")

    # 5. Reset index
    df = df.reset_index(drop=True)
    print("🔄 Reset index")

    print("✅ Cleaning complete")
    print("-------------------------\n")

    return df
cleaned_data = clean_f1_data(df)
cleaned_data.head(5)
# Out:
# 🚦 Starting cleaning process...
# 🧹 Removed duplicates: 0 rows
# ❓ Filled/Dropped missing values: 1261 → 1226 remaining
# ⏱️ Converted LapTime → seconds
# ⏱️ Converted Sector1Time → seconds
# ⏱️ Converted Sector2Time → seconds
# ⏱️ Converted Sector3Time → seconds
# 📊 Normalized numeric columns: ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife']
# 🔄 Reset index
# ✅ Cleaning complete
# -------------------------
#                      Time Driver  DriverNumber  LapNumber  Stint Compound  \
# 0  0 days 01:03:46.121000    VER             1        1.0    1.0   MEDIUM
# 1  0 days 01:05:19.554000    VER             1        2.0    1.0   MEDIUM
# 2  0 days 01:06:52.284000    VER             1        3.0    1.0   MEDIUM
# 3  0 days 01:08:25.064000    VER             1        4.0    1.0   MEDIUM
# 4  0 days 01:09:57.646000    VER             1        5.0    1.0   MEDIUM
#
#    TyreLife  FreshTyre   LapTime  Sector1Time  Sector2Time  Sector3Time  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

def time_to_seconds(x):
    """Convert 'M:SS.mmm', 'SS.mmm', or timedelta string to seconds (float)."""
    if pd.isna(x):
        return None
    try:
        s = str(x)
        if "days" in s:  # handle "0 days 00:01:37.167000"
            s = s.split("days")[-1].strip()
        if ":" in s:
            parts = s.split(":")
            if len(parts) == 3:  # HH:MM:SS.mmm
                h, m, sec = parts
                return int(h) * 3600 + int(m) * 60 + float(sec)
            elif len(parts) == 2:  # MM:SS.mmm
                m, sec = parts
                return int(m) * 60 + float(sec)
        return float(s)  # already seconds
    except:
        return None

def clean_f1_data(df, year="2023"):
    print("🔎 Initial data shape:", df.shape)

    keep_cols = ['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
                 'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time',
                 'Sector3Time', 'Team', 'Position', 'GP']
    df = df[keep_cols]
    print("✅ Kept important columns:", keep_cols)

    # Convert LapTime + Sectors to seconds
    for col in ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']:
        df[col] = df[col].apply(time_to_seconds)
    print("✅ Converted LapTime & Sector times to seconds")

    # Handle missing values
    before_drop = df.shape[0]
    df = df.dropna(subset=['LapTime', 'Compound'])
    after_drop = df.shape[0]
    print(f"🗑️ Dropped {before_drop - after_drop} rows with missing LapTime/Compound")

    missing_tyre = df['TyreLife'].isna().sum()
    df['TyreLife'] = df['TyreLife'].fillna(0).astype(int)
    print(f"🛠️ Filled {missing_tyre} missing TyreLife values with 0")

    missing_fresh = df['FreshTyre'].isna().sum()
    df['FreshTyre'] = df['FreshTyre'].fillna(False)
    print(f"🛠️ Filled {missing_fresh} missing FreshTyre values with False")

    # Remove outliers
    median_lap = df['LapTime'].median()
    before_outlier = df.shape[0]
    df = df[df['LapTime'] < 1.5 * median_lap]
    after_outlier = df.shape[0]
    print(f"⚡ Removed {before_outlier - after_outlier} outlier laps (>1.5x median lap time)")

    df = df.reset_index(drop=True)
    print("✅ Final raw-cleaned data shape:", df.shape)

    # Normalized version (for ML)
    df_norm = df.copy()
    scaler = MinMaxScaler()
    num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife']
    df_norm[num_cols] = scaler.fit_transform(df_norm[num_cols])
    print(f"📊 Created normalized dataset (scaled 0–1) for columns: {num_cols}")

    # Save both datasets
    raw_filename = f"cleaned_f1_data_{year}.csv"
    norm_filename = f"normalized_f1_data_{year}.csv"
    df.to_csv(raw_filename, index=False)
    df_norm.to_csv(norm_filename, index=False)
    print(f"💾 Saved cleaned dataset → {raw_filename}")
    print(f"💾 Saved normalized dataset → {norm_filename}")

    # Summary
    print("\n📋 --- Dataset Summary ---")
    print("Unique Drivers:", df['Driver'].nunique())
    print("Unique Teams:", df['Team'].nunique())
    print("Tyre Compounds used:", df['Compound'].unique().tolist())
    print("LapTime (seconds) min:", df['LapTime'].min(), "| max:", df['LapTime'].max())
    print("TyreLife (laps) min:", df['TyreLife'].min(), "| max:", df['TyreLife'].max())
    print("-------------------------\n")

    return df, df_norm
cleaned_df, normalized_df = clean_f1_data(df, year="2023")
# Out:
# 🔎 Initial data shape: (25393, 15)
# ✅ Kept important columns: ['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound', 'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'Team', 'Position', 'GP']
# C:\Users\VANSH\AppData\Local\Temp\ipykernel_17664\1023529657.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(time_to_seconds)
# C:\Users\VANSH\AppData\Local\Temp\ipykernel_17664\1023529657.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
cleaned_df.head(5)
# Out:
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    VER             1        1.0    1.0   MEDIUM         1       True
# 1    VER             1        2.0    1.0   MEDIUM         2       True
# 2    VER             1        3.0    1.0   MEDIUM         3       True
# 3    VER             1        4.0    1.0   MEDIUM         4       True
# 4    VER             1        5.0    1.0   MEDIUM         5       True
#
#    LapTime  Sector1Time  Sector2Time  Sector3Time             Team  Position  \
# 0   97.167          NaN       38.051       26.073  Red Bull Racing       2.0
# 1   93.433       29.616       38.000       25.817  Red Bull Racing       2.0
# 2   92.730       29.380       37.690       25.660  Red Bull Racing       2.0
# 3   92.780       29.407       37.650       25.723  Red Bull Racing       2.0
# 4   92.582       29.338       37.403       25.841  Red Bull Racing       1.0
#
#                    GP
# 0  Pre-Season Testing
# 1  Pre-Season Testing
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

def time_to_seconds(x):
    """Convert 'M:SS.mmm' or 'SS.mmm' to seconds (float)."""
    if pd.isna(x):
        return None
    try:
        if isinstance(x, str) and ":" in x:
            minutes, sec = x.split(":")
            return int(minutes) * 60 + float(sec)
        return float(x)
    except:
        return None

def clean_f1_data(session, year=2023, gp_name="GrandPrix", save_prefix="f1_cleaned"):
    """
    Clean and enrich F1 lap data with weather & track status.
    Saves both raw_cleaned and normalized versions to CSV.
    """
    print(f"🔎 Processing {year} - {gp_name}")

    # Load laps
    laps = session.laps.copy()
    keep_cols = ['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
                 'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time',
                 'Sector3Time', 'Team', 'Position']
    laps = laps[keep_cols]
    
    # Convert Lap/Sector times
    for col in ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']:
        laps[col] = laps[col].apply(time_to_seconds)
    
    # Add GP info
    laps['GP'] = gp_name

    # --- Weather Data ---
    weather = session.weather_data.copy()
    laps = laps.merge(weather, left_on='LapNumber', right_on='Time', how='left')
    laps = laps.rename(columns={
        'AirTemp': 'AirTemp_C',
        'TrackTemp': 'TrackTemp_C',
        'Humidity': 'Humidity_pct',
        'WindSpeed': 'WindSpeed_mps',
        'WindDirection': 'WindDir_deg',
        'Rainfall': 'Rain'
    }).drop(columns=['Time'])

    # --- Track Status ---
    track_status = session.track_status.copy()
    track_status['Time'] = pd.to_timedelta(track_status['Time'], unit='s')
    laps = laps.merge(track_status, left_on='LapNumber', right_on='Time', how='left')
    laps = laps.rename(columns={'Status': 'TrackStatus'}).drop(columns=['Time'])

    # Handle missing values
    laps = laps.dropna(subset=['LapTime', 'Compound'])
    laps['TyreLife'] = laps['TyreLife'].fillna(0).astype(int)
    laps['FreshTyre'] = laps['FreshTyre'].fillna(False)

    # Remove outliers
    median_lap = laps['LapTime'].median()
    laps = laps[laps['LapTime'] < 1.5 * median_lap]

    # Save non-normalized version
    raw_path = f"{save_prefix}_{year}_{gp_name}_raw.csv"
    laps.to_csv(raw_path, index=False)
    print(f"💾 Saved raw cleaned dataset → {raw_path}")

    # Normalized version
    scaler = MinMaxScaler()
    num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife',
                'AirTemp_C', 'TrackTemp_C', 'Humidity_pct', 'WindSpeed_mps']
    laps_norm = laps.copy()
    laps_norm[num_cols] = scaler.fit_transform(laps_norm[num_cols])
    norm_path = f"{save_prefix}_{year}_{gp_name}_normalized.csv"
    laps_norm.to_csv(norm_path, index=False)
    print(f"💾 Saved normalized dataset → {norm_path}")

    return laps, laps_norm

# %%
cleaned_df, normalized_df = clean_f1_data(df, save_prefix="f1_cleaned_2023_Bahrain")
# Out:
# 🔎 Processing 2023 - GrandPrix
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 cleaned_df, normalized_df = clean_f1_data(df, save_prefix="f1_cleaned_2023_Bahrain")
#
# Cell In[16], line 24, in clean_f1_data(session, year, gp_name, save_prefix)
#      21 print(f"🔎 Processing {year} - {gp_name}")
#      23 # Load laps
# ---> 24 laps = session.laps.copy()
#      25 keep_cols = ['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
#      26              'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time',
#      27              'Sector3Time', 'Team', 'Position']
#      28 laps = laps[keep_cols]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
# ...

# %%
clean_f1_2023 = pd.read_csv('cleaned_f1_data_2023.csv')
clean_f1_2023.head(5)
# Out:
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    VER             1        1.0    1.0   MEDIUM         1       True
# 1    VER             1        2.0    1.0   MEDIUM         2       True
# 2    VER             1        3.0    1.0   MEDIUM         3       True
# 3    VER             1        4.0    1.0   MEDIUM         4       True
# 4    VER             1        5.0    1.0   MEDIUM         5       True
#
#    LapTime  Sector1Time  Sector2Time  Sector3Time             Team  Position  \
# 0   97.167          NaN       38.051       26.073  Red Bull Racing       2.0
# 1   93.433       29.616       38.000       25.817  Red Bull Racing       2.0
# 2   92.730       29.380       37.690       25.660  Red Bull Racing       2.0
# 3   92.780       29.407       37.650       25.723  Red Bull Racing       2.0
# 4   92.582       29.338       37.403       25.841  Red Bull Racing       1.0
#
#                    GP
# 0  Pre-Season Testing
# 1  Pre-Season Testing
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import fastf1

def time_to_seconds(x):
    """Convert 'M:SS.mmm' or 'SS.mmm' to seconds (float)."""
    if pd.isna(x):
        return None
    try:
        if ":" in str(x):
            minutes, sec = str(x).split(":")
            return int(minutes) * 60 + float(sec)
        return float(x)
    except:
        return None


def clean_f1_data(df, save_prefix="f1_cleaned"):
    print("🔎 Initial data shape:", df.shape)

    # --- Keep important cols + weather + track status ---
    keep_cols = [
        'Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
        'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time',
        'Sector3Time', 'Team', 'Position', 'GP',
        # Weather
        'AirTemp', 'TrackTemp', 'Humidity', 'WindSpeed', 'WindDirection', 'Pressure',
        # Track status
        'TrackStatus'
    ]
    available_cols = [c for c in keep_cols if c in df.columns]
    df = df[available_cols]
    print("✅ Kept columns:", available_cols)

    # --- Convert times to seconds ---
    for col in ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']:
        if col in df.columns:
            df[col] = df[col].apply(time_to_seconds)
    print("✅ Converted LapTime & Sector times to seconds")

    # --- Handle missing values ---
    before_drop = df.shape[0]
    df = df.dropna(subset=['LapTime', 'Compound'])
    after_drop = df.shape[0]
    print(f"🗑️ Dropped {before_drop - after_drop} rows with missing LapTime/Compound")

    if 'TyreLife' in df.columns:
        missing_tyre = df['TyreLife'].isna().sum()
        df['TyreLife'] = df['TyreLife'].fillna(0).astype(int)
        print(f"🛠️ Filled {missing_tyre} missing TyreLife values with 0")

    if 'FreshTyre' in df.columns:
        missing_fresh = df['FreshTyre'].isna().sum()
        df['FreshTyre'] = df['FreshTyre'].fillna(False)
        print(f"🛠️ Filled {missing_fresh} missing FreshTyre values with False")

    # --- Outlier removal ---
    median_lap = df['LapTime'].median()
    before_outlier = df.shape[0]
    df = df[df['LapTime'] < 1.5 * median_lap]
    after_outlier = df.shape[0]
    print(f"⚡ Removed {before_outlier - after_outlier} outlier laps (>1.5x median lap time)")

    # --- Save raw (non-normalized) version ---
    raw_path = f"{save_prefix}_raw.csv"
    df.to_csv(raw_path, index=False)
    print(f"💾 Saved RAW cleaned data → {raw_path}")

    # --- Normalize numeric columns ---
    scaler = MinMaxScaler()
    num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife',
                'AirTemp', 'TrackTemp', 'Humidity', 'WindSpeed', 'Pressure']
    num_cols = [c for c in num_cols if c in df.columns]

    norm_df = df.copy()
    norm_df[num_cols] = scaler.fit_transform(norm_df[num_cols])
    print(f"📊 Normalized numeric columns: {num_cols}")

    # --- Save normalized version ---
    norm_path = f"{save_prefix}_normalized.csv"
    norm_df.to_csv(norm_path, index=False)
    print(f"💾 Saved NORMALIZED cleaned data → {norm_path}")

    # --- Summary ---
    print("\n📋 --- Dataset Summary ---")
    print("Unique Drivers:", df['Driver'].nunique())
    print("Unique Teams:", df['Team'].nunique() if 'Team' in df else "N/A")
    print("Tyre Compounds used:", df['Compound'].unique().tolist())
    print("LapTime range (raw):", df['LapTime'].min(), "→", df['LapTime'].max())
    print("-------------------------\n")

    return df, norm_df

# %%
import pandas as pd

# Your current datasets
cleaned_df = pd.read_csv("cleaned_f1_data.csv")           # readable version
normalized_df = pd.read_csv("normalized_f1_data_2023.csv")  # ML version
import fastf1

fastf1.Cache.enable_cache('f1_cache')  # ensure caching is enabled

def get_weather_and_trackstatus(year, gp_name):
    session = fastf1.get_session(year, gp_name, 'R')  # 'R' for race
    session.load()

    # Weather data: get relevant columns
    weather = session.weather_data[['Time', 'AirTemp', 'TrackTemp', 'Humidity',
                                    'WindSpeed', 'WindDirection', 'Pressure']].copy()

    # Track status
    track_status = session.track_status[['Time', 'Status']].copy().rename(columns={'Status': 'TrackStatus'})

    # Merge weather + track status on Time
    weather_status = pd.merge_asof(weather.sort_values('Time'),
                                   track_status.sort_values('Time'),
                                   on='Time', direction='backward')
    return weather_status
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 4
#       1 import pandas as pd
#       3 # Your current datasets
# ----> 4 cleaned_df = pd.read_csv("cleaned_f1_data.csv")           # readable version
#       5 normalized_df = pd.read_csv("normalized_f1_data_2023.csv")  # ML version
#       6 import fastf1
#
# ...

# %%
clean_f1_2023['LapTime']
# Out:
# 0        97.167
# 1        93.433
# 2        92.730
# 3        92.780
# 4        92.582
#           ...
# 24576    90.445
# 24577    90.207
# 24578    90.252
# 24579    90.429
# 24580    91.256
# Name: LapTime, Length: 24581, dtype: float64

# %%
clean_f1_2023.columns
# Out:
# Index(['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound', 'TyreLife',
#        'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Team', 'Position', 'GP'],
#       dtype='object')

# %%
import fastf1
import pandas as pd
import logging
from fastf1 import plotting

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler("f1_data_build.log"),  # log to file
        logging.StreamHandler()                    # also print to console
    ]
)

def rebuild_2023_with_conditions():
    fastf1.Cache.enable_cache('f1_cache')  # your cache dir

    all_clean = []
    all_normal = []

    races_2023 = fastf1.get_event_schedule(2023, include_testing=True)

    for _, row in races_2023.iterrows():
        event_name = row['EventName']
        session_name = 'R'  # race session

        logging.info(f"Processing {event_name} ...")

        try:
            session = fastf1.get_session(2023, event_name, session_name)
            session.load()
            logging.info(f"Session loaded for {event_name}")

            laps = session.laps.copy()
            laps['GP'] = event_name

            # Keep useful columns
            keep_cols = ['Time', 'Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
                         'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time',
                         'Sector3Time', 'Team', 'Position', 'GP']

            # Merge weather
            weather = session.weather_data
            laps = pd.merge_asof(laps.sort_values('Time'), 
                                 weather.sort_values('Time'),
                                 on='Time', direction='nearest')
            logging.info(f"Weather merged for {event_name}")

            # Merge track status
            track_status = session.track_status_data
            laps = pd.merge_asof(laps.sort_values('Time'),
                                 track_status[['Time', 'TrackStatus']].sort_values('Time'),
                                 on='Time', direction='nearest')
            logging.info(f"Track status merged for {event_name}")

            # Append clean data
            all_clean.append(laps[keep_cols + list(weather.columns[1:]) + ['TrackStatus']])

            # Normalized version for ML
            df_norm = laps.copy()
            for col in ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']:
                if pd.api.types.is_timedelta64_dtype(df_norm[col]):
                    df_norm[col] = df_norm[col].dt.total_seconds()
            all_normal.append(df_norm[keep_cols + list(weather.columns[1:]) + ['TrackStatus']])

            logging.info(f"{event_name} processed successfully ✅")

        except Exception as e:
            logging.error(f"Failed for {event_name}: {e}", exc_info=True)

    # Save combined CSVs
    cleaned_all = pd.concat(all_clean)
    norm_all = pd.concat(all_normal)

    cleaned_all.to_csv('cleaned_f1_data_2023_with_conditions.csv', index=False)
    norm_all.to_csv('normalized_f1_data_2023_with_conditions.csv', index=False)

    logging.info("✅ All races processed and saved with weather + track status!")

# Run it
rebuild_2023_with_conditions()
# Out:
# 2025-08-22 21:43:28,382 - INFO - Processing Pre-Season Testing ...
# events      WARNING 	Correcting user input 'Pre-Season Testing' to 'British Grand Prix'
# 2025-08-22 21:43:28,450 - WARNING - Correcting user input 'Pre-Season Testing' to 'British Grand Prix'
# core           INFO 	Loading data for British Grand Prix - Race [v3.6.0]
# 2025-08-22 21:43:28,456 - INFO - Loading data for British Grand Prix - Race [v3.6.0]
# req            INFO 	Using cached data for session_info
# 2025-08-22 21:43:28,456 - INFO - Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# 2025-08-22 21:43:28,470 - INFO - Using cached data for driver_info
# 2025-08-22 21:43:29,200 - DEBUG - Failed to parse timestamp '-1:52:18.651' in Ergastresponse.
# req            INFO 	Using cached data for session_status_data
# 2025-08-22 21:43:29,288 - INFO - Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# ...

# %%
import fastf1
import pandas as pd
import logging
from fastf1.core import Laps

# Setup logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

def rebuild_2023_with_all_sessions(output_cleaned="cleaned_f1_data_2023.csv",
                                   output_normalized="normalized_f1_data_2023.csv"):
    all_data = []
    races = fastf1.get_event_schedule(2023, include_testing=False)  # Only official season

    for _, event in races.iterrows():
        gp_name = event['EventName']
        logging.info(f"Processing {gp_name} {event['EventDate'].year}")

        # Go through each session: FP1, FP2, FP3, Q, R
        for session_type in ["FP1", "FP2", "FP3", "Q", "R"]:
            try:
                logging.info(f"  Loading {session_type}...")
                session = fastf1.get_session(event['EventDate'].year, event['RoundNumber'], session_type)
                session.load(weather=True)

                # Extract laps
                laps = session.laps
                if laps.empty:
                    logging.warning(f"    No data for {gp_name} {session_type}")
                    continue

                # Add weather info
                weather = session.weather_data
                laps = laps.merge(weather, on="Time", how="left")

                # Add track status if available
                try:
                    track_status = session.get_track_status()
                    laps = laps.merge(track_status, on="Time", how="left")
                except Exception as e:
                    logging.warning(f"    No track status for {gp_name} {session_type} ({e})")

                # Add identifiers
                laps["GP"] = gp_name
                laps["SessionType"] = session_type

                all_data.append(laps)

            except Exception as e:
                logging.error(f"  Failed to process {gp_name} {session_type}: {e}")

    # Combine everything
    if not all_data:
        logging.error("No data extracted!")
        return

    full_df = pd.concat(all_data, ignore_index=True)

    # Select useful columns
    keep_cols = [
        "Driver", "DriverNumber", "LapNumber", "Stint", "Compound", "TyreLife",
        "FreshTyre", "LapTime", "Sector1Time", "Sector2Time", "Sector3Time",
        "Team", "Position", "GP", "SessionType", "Time",
        "AirTemp", "TrackTemp", "Humidity", "Pressure", "Rainfall", "WindSpeed", "WindDirection",
        "Status"  # track status
    ]
    full_df = full_df[[c for c in keep_cols if c in full_df.columns]]

    # Save cleaned (human readable)
    full_df.to_csv(output_cleaned, index=False)
    logging.info(f"Saved cleaned data: {output_cleaned}")

    # Normalized version (LapTime + sectors to seconds)
    normalized_df = full_df.copy()
    for col in ["LapTime", "Sector1Time", "Sector2Time", "Sector3Time"]:
        if col in normalized_df:
            normalized_df[col] = pd.to_timedelta(normalized_df[col]).dt.total_seconds()

    normalized_df.to_csv(output_normalized, index=False)
    logging.info(f"Saved normalized data: {output_normalized}")

    return full_df, normalized_df


# Run pipeline
cleaned, normalized = rebuild_2023_with_all_sessions()
# Out:
# 2025-08-22 22:00:15,658 - INFO - Processing Bahrain Grand Prix 2023
# 2025-08-22 22:00:15,668 - INFO -   Loading FP1...
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 1 [v3.6.0]
# 2025-08-22 22:00:15,792 - INFO - Loading data for Bahrain Grand Prix - Practice 1 [v3.6.0]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-08-22 22:00:15,799 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-08-22 22:00:15,802 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-08-22 22:00:16,462 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-08-22 22:00:16,466 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-08-22 22:00:16,469 - INFO - Fetching driver list...
# ...

# %%
import fastf1
from fastf1.ergast import Ergast

# Just try a very light request, e.g. Ergast API (not the heavy live timing API)
ergast = Ergast()
try:
    result = ergast.get_race(2023, 1)  # Bahrain GP metadata
    print("API is working ✅, safe to proceed.")
except Exception as e:
    print("Still rate-limited or another error:", e)
# Out:
# Still rate-limited or another error: 'Ergast' object has no attribute 'get_race'

# %%
import fastf1
from fastf1.ergast import Ergast

ergast = Ergast()

try:
    # Fetch results of Bahrain GP 2023 (Round 1)
    results = ergast.get_race_results(season=2023, round=1)
    print("✅ Ergast API is working, you are not rate-limited.")
except Exception as e:
    print("⏳ Still rate-limited or another error:", e)
# Out:
# ✅ Ergast API is working, you are not rate-limited.

# %%
import fastf1
import pandas as pd
import logging

logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

def extract_gp_data(year: int, gp_name: str, output_prefix="f1_data"):
    """
    Extract FP, Q, and R sessions for one Grand Prix, with weather + track status merged.
    Saves two CSVs: cleaned (readable) and normalized (for ML).
    """
    fastf1.Cache.enable_cache("f1_cache")  # <-- set your cache folder

    session_types = ["FP1", "FP2", "FP3", "Q", "R"]
    all_dfs = []

    for stype in session_types:
        try:
            logging.info(f"Loading {gp_name} {stype}...")
            session = fastf1.get_session(year, gp_name, stype)
            session.load(weather=True)

            laps = session.laps.copy()
            if laps.empty:
                logging.warning(f"No laps found for {gp_name} {stype}, skipping...")
                continue

            # Add GP + session info
            laps["GP"] = gp_name
            laps["SessionType"] = stype

            # Keep the required columns
            keep_cols = [
                "Driver", "DriverNumber", "LapNumber", "Stint", "Compound",
                "TyreLife", "FreshTyre", "LapTime", "Sector1Time", "Sector2Time",
                "Sector3Time", "Team", "Position", "Time", "GP", "SessionType"
            ]
            laps = laps[keep_cols]

            # Merge with weather (nearest timestamp)
            weather = session.weather_data.copy()
            merged = pd.merge_asof(
                laps.sort_values("Time"),
                weather.sort_values("Time"),
                on="Time",
                direction="nearest"
            )

            # Merge with track status (if available)
            if hasattr(session, "track_status"):
                tstatus = session.track_status.copy()
                merged = pd.merge_asof(
                    merged.sort_values("Time"),
                    tstatus.sort_values("Time"),
                    on="Time",
                    direction="nearest"
                )

            all_dfs.append(merged)

        except Exception as e:
            logging.error(f"Failed {gp_name} {stype}: {e}")

    if not all_dfs:
        logging.error(f"No data collected for {gp_name}.")
        return

    full_df = pd.concat(all_dfs, ignore_index=True)

    # Save readable
    cleaned_path = f"{output_prefix}_{year}_{gp_name.replace(' ', '_')}_cleaned.csv"
    full_df.to_csv(cleaned_path, index=False)
    logging.info(f"Saved cleaned data → {cleaned_path}")

    # Save normalized (convert LapTime/Sectors to seconds)
    norm_df = full_df.copy()
    for col in ["LapTime", "Sector1Time", "Sector2Time", "Sector3Time"]:
        norm_df[col] = pd.to_timedelta(norm_df[col]).dt.total_seconds()

    norm_path = f"{output_prefix}_{year}_{gp_name.replace(' ', '_')}_normalized.csv"
    norm_df.to_csv(norm_path, index=False)
    logging.info(f"Saved normalized data → {norm_path}")
extract_gp_data(2023, 'Pre-Season Testing')
# Out:
# 2025-08-22 23:30:35,679 - INFO - Loading Pre-Season Testing FP1...
# events      WARNING 	Correcting user input 'Pre-Season Testing' to 'British Grand Prix'
# 2025-08-22 23:30:36,487 - WARNING - Correcting user input 'Pre-Season Testing' to 'British Grand Prix'
# core           INFO 	Loading data for British Grand Prix - Practice 1 [v3.6.0]
# 2025-08-22 23:30:36,525 - INFO - Loading data for British Grand Prix - Practice 1 [v3.6.0]
# req            INFO 	Using cached data for session_info
# 2025-08-22 23:30:36,633 - INFO - Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# 2025-08-22 23:30:36,691 - INFO - Using cached data for driver_info
# 2025-08-22 23:30:37,325 - DEBUG - Failed to parse timestamp '-1:52:18.651' in Ergastresponse.
# req            INFO 	Using cached data for session_status_data
# 2025-08-22 23:30:37,475 - INFO - Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# ...

# %%
import pandas as pd
df = pd.read_csv('cleaned_f1_data.csv')
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('cleaned_f1_data.csv')
#       3 df.head(20)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('cleaned_f1_data_2023.csv')
#df[(df['GP'] == 'Bahrain Grand Prix') & (df['Driver'] == 'VER')]
#df['GP'].value_counts()
df
# Out:
# C:\Users\VANSH\AppData\Local\Temp\ipykernel_18228\1395952835.py:2: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('cleaned_f1_data_2023.csv')
#       Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0        VER             1        1.0    1.0   MEDIUM       1.0       True
# 1        VER             1        2.0    1.0   MEDIUM       2.0       True
# 2        VER             1        3.0    1.0   MEDIUM       3.0       True
# 3        VER             1        4.0    2.0   MEDIUM       4.0      False
# 4        VER             1        5.0    2.0   MEDIUM       5.0      False
# ...      ...           ...        ...    ...      ...       ...        ...
# 37471    LEC            16       52.0    2.0     HARD      29.0       True
# 37472    LEC            16       53.0    2.0     HARD      30.0       True
# 37473    LEC            16       54.0    2.0     HARD      31.0       True
# ...

# %%
df.columns
# Out:
# Index(['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound', 'TyreLife',
#        'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Team', 'Position', 'GP', 'SessionType', 'Time', 'AirTemp', 'TrackTemp',
#        'Humidity', 'Pressure', 'Rainfall', 'WindSpeed', 'WindDirection'],
#       dtype='object')

# %%
df['GP'].value_counts()
# Out:
# GP
# Monaco Grand Prix           3437
# Spanish Grand Prix          3103
# Canadian Grand Prix         2863
# Miami Grand Prix            2790
# Hungarian Grand Prix        2745
# British Grand Prix          2679
# Saudi Arabian Grand Prix    2647
# Australian Grand Prix       2576
# Bahrain Grand Prix          2556
# Austrian Grand Prix         2335
# Dutch Grand Prix            1820
# Azerbaijan Grand Prix       1708
# Belgian Grand Prix          1271
# Singapore Grand Prix        1088
# United States Grand Prix    1014
# Qatar Grand Prix            1006
# Italian Grand Prix           958
# Japanese Grand Prix          880
# Name: count, dtype: int64

# %%
import pandas as pd 
import fastf1
fastf1.Cache.enable_cache('f1_cache')
laps_data = pd.read_csv('f1_2023_lapdata.csv')
laps_data
# Out:
#                          Time Driver  DriverNumber  LapNumber  Stint Compound  \
# 0      0 days 01:03:46.121000    VER             1        1.0    1.0   MEDIUM
# 1      0 days 01:05:19.554000    VER             1        2.0    1.0   MEDIUM
# 2      0 days 01:06:52.284000    VER             1        3.0    1.0   MEDIUM
# 3      0 days 01:08:25.064000    VER             1        4.0    1.0   MEDIUM
# 4      0 days 01:09:57.646000    VER             1        5.0    1.0   MEDIUM
# ...                       ...    ...           ...        ...    ...      ...
# 25388  0 days 02:23:40.131000    MAG            20       53.0    3.0     HARD
# 25389  0 days 02:25:10.338000    MAG            20       54.0    3.0     HARD
# 25390  0 days 02:26:40.590000    MAG            20       55.0    3.0     HARD
# 25391  0 days 02:28:11.019000    MAG            20       56.0    3.0     HARD
# 25392  0 days 02:29:42.275000    MAG            20       57.0    3.0     HARD
#
# ...

# %%
laps_data.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
#        'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time',
#        'Sector3Time', 'Team', 'Position', 'GP'],
#       dtype='object')

# %%
import fastf1
import pandas as pd
from tqdm import tqdm

# Enable cache
fastf1.Cache.enable_cache('f1_cache')

# Load existing dataset
df_master = pd.read_csv("cleaned_f1_data_2023.csv")

# Missing GPs we need
missing_gps = {
    "Mexico City Grand Prix": 20,
    "São Paulo Grand Prix": 21,
    "Las Vegas Grand Prix": 22,
    "Abu Dhabi Grand Prix": 23
}

year = 2023
all_new_data = []

# Iterate through missing races
for gp_name, round_no in tqdm(missing_gps.items()):
    sessions = ["FP1", "FP2", "FP3", "Q", "R"]  # Free practices, Quali, Race
    
    for session_type in sessions:
        try:
            session = fastf1.get_session(year, round_no, session_type)
            session.load(laps=True, telemetry=False, weather=True)
            
            # Extract laps
            laps = session.laps
            if laps.empty:
                continue
            
            # Add GP + session info
            laps["GP"] = gp_name
            laps["SessionType"] = session_type
            
            # Align schema
            cols = ['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound', 'TyreLife',
                    'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
                    'Team', 'Position', 'GP', 'SessionType', 'Time', 
                    'AirTemp', 'TrackTemp', 'Humidity', 'Pressure', 'Rainfall', 
                    'WindSpeed', 'WindDirection']
            
            # Add weather columns if available
            if session.weather_data is not None:
                weather = session.weather_data
                # Simplify by merging nearest weather sample on lap start time
                laps = laps.merge(weather, how="left", left_on="Time", right_on="Time")
            else:
                for col in ['AirTemp','TrackTemp','Humidity','Pressure','Rainfall','WindSpeed','WindDirection']:
                    laps[col] = pd.NA
            
            # Keep only required columns (fill missing with NaN)
            for col in cols:
                if col not in laps.columns:
                    laps[col] = pd.NA
            laps = laps[cols]
            
            all_new_data.append(laps)
        
        except Exception as e:
            print(f"Error loading {gp_name} - {session_type}: {e}")

# Combine new races
df_new = pd.concat(all_new_data, ignore_index=True)

# Append to master dataset
df_final = pd.concat([df_master, df_new], ignore_index=True)

# Save
df_final.to_csv("cleaned_f1_2023_updated.csv", index=False)

print("✅ Appended missing races. Saved as cleaned_f1_2023_updated.csv")
# Out:
# C:\Users\VANSH\AppData\Local\Temp\ipykernel_18228\3369204434.py:9: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_master = pd.read_csv("cleaned_f1_data_2023.csv")
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]core           INFO 	Loading data for São Paulo Grand Prix - Practice 1 [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
df_updated = pd.read_csv('cleaned_f1_2023_updated.csv')
df[df['GP'] == 'Las Vegas Grand Prix']
# Out:
# Empty DataFrame
# Columns: [Driver, DriverNumber, LapNumber, Stint, Compound, TyreLife, FreshTyre, LapTime, Sector1Time, Sector2Time, Sector3Time, Team, Position, GP, SessionType, Time, AirTemp, TrackTemp, Humidity, Pressure, Rainfall, WindSpeed, WindDirection]
# Index: []
#
# [0 rows x 23 columns]

# %%
import pandas as pd

# Step 1: Make sure you’re opening the correct file
df = pd.read_csv("cleaned_f1_2023_updated.csv")
print(df.shape)   # should be larger than your old dataset
print(df['GP'].unique())  # Las Vegas GP should appear here
# Out:
# (44533, 23)
# ['Bahrain Grand Prix' 'Saudi Arabian Grand Prix' 'Australian Grand Prix'
#  'Azerbaijan Grand Prix' 'Miami Grand Prix' 'Monaco Grand Prix'
#  'Spanish Grand Prix' 'Canadian Grand Prix' 'Austrian Grand Prix'
#  'British Grand Prix' 'Hungarian Grand Prix' 'Belgian Grand Prix'
#  'Dutch Grand Prix' 'Italian Grand Prix' 'Singapore Grand Prix'
#  'Japanese Grand Prix' 'Qatar Grand Prix' 'United States Grand Prix'
#  'Mexico City Grand Prix' 'São Paulo Grand Prix' 'Las Vegas Grand Prix']

# %%
df['GP'].value_counts()
# Out:
# GP
# Monaco Grand Prix           3437
# Spanish Grand Prix          3103
# Canadian Grand Prix         2863
# Miami Grand Prix            2790
# Hungarian Grand Prix        2745
# British Grand Prix          2679
# Saudi Arabian Grand Prix    2647
# Las Vegas Grand Prix        2625
# Australian Grand Prix       2576
# Bahrain Grand Prix          2556
# São Paulo Grand Prix        2463
# Austrian Grand Prix         2335
# Mexico City Grand Prix      1969
# Dutch Grand Prix            1820
# Azerbaijan Grand Prix       1708
# Belgian Grand Prix          1271
# Singapore Grand Prix        1088
# United States Grand Prix    1014
# Qatar Grand Prix            1006
# Italian Grand Prix           958
# Japanese Grand Prix          880
# Name: count, dtype: int64

# %%
df[df['GP'] == '']
# Out:
#       Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 41908    SAR             2        1.0    1.0   MEDIUM       1.0       True
# 41909    SAR             2        2.0    1.0   MEDIUM       2.0       True
# 41910    SAR             2        3.0    1.0   MEDIUM       3.0       True
# 41911    SAR             2        4.0    1.0   MEDIUM       4.0       True
# 41912    SAR             2        5.0    1.0   MEDIUM       5.0       True
# ...      ...           ...        ...    ...      ...       ...        ...
# 44528    MAG            20       53.0    3.0     HARD      31.0       True
# 44529    MAG            20       54.0    3.0     HARD      32.0       True
# 44530    MAG            20       55.0    3.0     HARD      33.0       True
# 44531    MAG            20       56.0    3.0     HARD      34.0       True
# 44532    MAG            20       57.0    3.0     HARD      35.0       True
#
# ...

# %%
import fastf1
import pandas as pd

# Enable cache
fastf1.Cache.enable_cache('f1_cache')

# Abu Dhabi = Round 22 in 2023
sessions = ['FP1', 'FP2', 'FP3', 'Q', 'R']
abu_dhabi_data = []

for sess in sessions:
    try:
        session = fastf1.get_session(2023, 22, sess)
        session.load()
        
        # laps with required columns
        laps = session.laps[[
            'Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
            'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time',
            'Sector2Time', 'Sector3Time', 'Team', 'Position'
        ]].copy()

        laps['GP'] = "Abu Dhabi Grand Prix"
        laps['SessionType'] = sess
        laps['Time'] = laps.index

        # Weather data (same length alignment issue possible → fill later)
        weather = session.weather_data
        for col in ['AirTemp','TrackTemp','Humidity','Pressure','Rainfall','WindSpeed','WindDirection']:
            laps[col] = weather[col].reindex(laps.index, method='ffill').values

        abu_dhabi_data.append(laps)

    except Exception as e:
        print(f"Error loading Abu Dhabi {sess}: {e}")

abu_dhabi_df = pd.concat(abu_dhabi_data, ignore_index=True)

# Now append to your existing cleaned dataset
full_df = pd.read_csv("cleaned_f1_2023_updated.csv")
full_df = pd.concat([full_df, abu_dhabi_df], ignore_index=True)

full_df.to_csv("cleaned_f1_2023_final.csv", index=False)
# Out:
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 1 [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['2', '3', '10', '18', '20', '22', '29', '34', '36', '37', '39', '42', '45', '50', '55', '61', '63', '77', '81', '98']
# ...

# %%
df_final = pd.read_csv('cleaned_f1_2023_final.csv')
#df[df['GP'] == 'Abu Dhabi Grand Prix']
df['GP'].value_counts()
# Out:
# GP
# Monaco Grand Prix           3437
# Spanish Grand Prix          3103
# Canadian Grand Prix         2863
# Miami Grand Prix            2790
# Hungarian Grand Prix        2745
# British Grand Prix          2679
# Saudi Arabian Grand Prix    2647
# Las Vegas Grand Prix        2625
# Australian Grand Prix       2576
# Bahrain Grand Prix          2556
# São Paulo Grand Prix        2463
# Austrian Grand Prix         2335
# Mexico City Grand Prix      1969
# Dutch Grand Prix            1820
# Azerbaijan Grand Prix       1708
# Belgian Grand Prix          1271
# Singapore Grand Prix        1088
# United States Grand Prix    1014
# Qatar Grand Prix            1006
# Italian Grand Prix           958
# Japanese Grand Prix          880
# Name: count, dtype: int64

# %%
import fastf1
import pandas as pd

# Enable cache
fastf1.Cache.enable_cache('f1_cache')

# Abu Dhabi = Round 22 in 2023
sessions = ['FP1', 'FP2', 'FP3', 'Q', 'R']
abu_dhabi_data = []

for sess in sessions:
    try:
        session = fastf1.get_session(2023, 22, sess)
        session.load()
        
        # laps with required columns
        laps = session.laps[[
            'Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound',
            'TyreLife', 'FreshTyre', 'LapTime', 'Sector1Time',
            'Sector2Time', 'Sector3Time', 'Team', 'Position'
        ]].copy()

        laps['GP'] = "Abu Dhabi Grand Prix"
        laps['SessionType'] = sess
        laps['Time'] = laps.index

        # Weather data (same length alignment issue possible → fill later)
        weather = session.weather_data
        for col in ['AirTemp','TrackTemp','Humidity','Pressure','Rainfall','WindSpeed','WindDirection']:
            laps[col] = weather[col].reindex(laps.index, method='ffill').values

        abu_dhabi_data.append(laps)

    except Exception as e:
        print(f"Error loading Abu Dhabi {sess}: {e}")

abu_dhabi_df = pd.concat(abu_dhabi_data, ignore_index=True)

# Now append to your existing cleaned dataset
full_df = pd.read_csv("cleaned_f1_2023_updated.csv")
full_df = pd.concat([full_df, abu_dhabi_df], ignore_index=True)

full_df.to_csv("cleaned_f1_2023_final.csv", index=False)
# Out:
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 1 [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['2', '3', '10', '18', '20', '22', '29', '34', '36', '37', '39', '42', '45', '50', '55', '61', '63', '77', '81', '98']
# ...

# %%
df_final = pd.read_csv('cleaned_f1_2023_final.csv')
#df_final[df_final['GP'] == 'Abu Dhabi Grand Prix']
df_final['GP'].value_counts()
# Out:
# GP
# Monaco Grand Prix           3437
# Spanish Grand Prix          3103
# Canadian Grand Prix         2863
# Miami Grand Prix            2790
# Hungarian Grand Prix        2745
# British Grand Prix          2679
# Saudi Arabian Grand Prix    2647
# Abu Dhabi Grand Prix        2625
# Las Vegas Grand Prix        2625
# Australian Grand Prix       2576
# Bahrain Grand Prix          2556
# São Paulo Grand Prix        2463
# Austrian Grand Prix         2335
# Mexico City Grand Prix      1969
# Dutch Grand Prix            1820
# Azerbaijan Grand Prix       1708
# Belgian Grand Prix          1271
# Singapore Grand Prix        1088
# United States Grand Prix    1014
# Qatar Grand Prix            1006
# Italian Grand Prix           958
# Japanese Grand Prix          880
# Name: count, dtype: int64

# %%
import pandas as pd
import fastf1
fastf1.Cache.enable_cache('f1_cache')
final_2023 = pd.read_csv('cleaned_f1_2023_final.csv')
final_2023['GP'].unique()
# Out:
# array(['Bahrain Grand Prix', 'Saudi Arabian Grand Prix',
#        'Australian Grand Prix', 'Azerbaijan Grand Prix',
#        'Miami Grand Prix', 'Monaco Grand Prix', 'Spanish Grand Prix',
#        'Canadian Grand Prix', 'Austrian Grand Prix', 'British Grand Prix',
#        'Hungarian Grand Prix', 'Belgian Grand Prix', 'Dutch Grand Prix',
#        'Italian Grand Prix', 'Singapore Grand Prix',
#        'Japanese Grand Prix', 'Qatar Grand Prix',
#        'United States Grand Prix', 'Mexico City Grand Prix',
#        'São Paulo Grand Prix', 'Las Vegas Grand Prix',
#        'Abu Dhabi Grand Prix'], dtype=object)

# %%
import fastf1

session = fastf1.get_session(2023, "Abu Dhabi", "R")
session.load()
weather = session.weather_data
df_weather = pd.DataFrame(weather)
df_weather.head()
# Out:
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '63', '11', '4', '81', '14', '22', '44', '18', '3', '31', '10', '23', '27', '2', '24', '55', '77', '20']
# ...

# %%
final_2023[(final_2023['SessionType'] == 'R') & (final_2023['Driver'] == 'VER') & (final_2023['GP'] == "Bahrain Grand Prix")]
# Out:
#      Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 1500    VER             1        1.0    1.0     SOFT       4.0      False
# 1501    VER             1        2.0    1.0     SOFT       5.0      False
# 1502    VER             1        3.0    1.0     SOFT       6.0      False
# 1503    VER             1        4.0    1.0     SOFT       7.0      False
# 1504    VER             1        5.0    1.0     SOFT       8.0      False
# 1505    VER             1        6.0    1.0     SOFT       9.0      False
# 1506    VER             1        7.0    1.0     SOFT      10.0      False
# 1507    VER             1        8.0    1.0     SOFT      11.0      False
# 1508    VER             1        9.0    1.0     SOFT      12.0      False
# 1509    VER             1       10.0    1.0     SOFT      13.0      False
# 1510    VER             1       11.0    1.0     SOFT      14.0      False
# 1511    VER             1       12.0    1.0     SOFT      15.0      False
# ...

# %%
weather_cols = ['AirTemp', 'TrackTemp', 'Humidity', 'Pressure', 'Rainfall', 'WindSpeed', 'WindDirection']
driver_df = final_2023.drop(columns=weather_cols, inplace= True)
print('Dropped the weather columns', weather_cols)
# Out:
# Dropped the weather columns ['AirTemp', 'TrackTemp', 'Humidity', 'Pressure', 'Rainfall', 'WindSpeed', 'WindDirection']

# %%
final_2023.columns
# Out:
# Index(['Driver', 'DriverNumber', 'LapNumber', 'Stint', 'Compound', 'TyreLife',
#        'FreshTyre', 'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Team', 'Position', 'GP', 'SessionType', 'Time'],
#       dtype='object')

# %%
final_2023.head()
# Out:
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    VER             1        1.0    1.0   MEDIUM       1.0       True
# 1    VER             1        2.0    1.0   MEDIUM       2.0       True
# 2    VER             1        3.0    1.0   MEDIUM       3.0       True
# 3    VER             1        4.0    2.0   MEDIUM       4.0      False
# 4    VER             1        5.0    2.0   MEDIUM       5.0      False
#
#                   LapTime             Sector1Time             Sector2Time  \
# 0                     NaN                     NaN  0 days 00:01:09.383000
# 1  0 days 00:01:35.429000  0 days 00:00:30.535000  0 days 00:00:41.153000
# 2                     NaN  0 days 00:00:52.814000  0 days 00:01:12.105000
# 3                     NaN  0 days 00:01:09.699000  0 days 00:01:07.418000
# 4  0 days 00:01:53.662000  0 days 00:00:30.271000  0 days 00:00:55.102000
#
#               Sector3Time             Team  Position                  GP  \
# ...

# %%
# ---- Clean driver dataset ----
cleaned_df = final_2023.copy()

# Convert time-like columns to seconds
time_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']
for col in time_cols:
    cleaned_df[col] = cleaned_df[col].apply(time_to_seconds)

# Drop rows missing LapTime or Compound
before_drop = cleaned_df.shape[0]
cleaned_df = cleaned_df.dropna(subset=['LapTime', 'Compound'])
print(f"🗑️ Dropped {before_drop - cleaned_df.shape[0]} rows with missing LapTime/Compound")

# Handle TyreLife missing
missing_tyre = cleaned_df['TyreLife'].isna().sum()
cleaned_df['TyreLife'] = cleaned_df['TyreLife'].fillna(0).astype(int)
print(f"🛠️ Filled {missing_tyre} missing TyreLife values with 0")

# Handle FreshTyre missing
missing_fresh = cleaned_df['FreshTyre'].isna().sum()
cleaned_df['FreshTyre'] = cleaned_df['FreshTyre'].fillna(False).astype(int)  # 0/1
print(f"🛠️ Filled {missing_fresh} missing FreshTyre values with False")

# Remove outlier laps (1.5x median LapTime)
median_lap = cleaned_df['LapTime'].median()
before_outlier = cleaned_df.shape[0]
cleaned_df = cleaned_df[cleaned_df['LapTime'] < 1.5 * median_lap]
print(f"⚡ Removed {before_outlier - cleaned_df.shape[0]} outlier laps")

# Reset index
cleaned_df = cleaned_df.reset_index(drop=True)

# Save cleaned dataset
cleaned_df.to_csv("driver_data_cleaned.csv", index=False)
print("💾 Saved cleaned dataset → driver_data_cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 7
#       5 time_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']
#       6 for col in time_cols:
# ----> 7     cleaned_df[col] = cleaned_df[col].apply(time_to_seconds)
#       9 # Drop rows missing LapTime or Compound
#      10 before_drop = cleaned_df.shape[0]
#
# NameError: name 'time_to_seconds' is not defined

# %%
import pandas as pd

def time_to_seconds(t):
    """
    Convert timedelta or time string into float seconds.
    Handles NaN gracefully.
    """
    if pd.isna(t):
        return None
    
    # If it's already a timedelta
    if isinstance(t, pd.Timedelta):
        return t.total_seconds()
    
    # If it's a string like "0 days 00:01:38.123000"
    try:
        return pd.to_timedelta(t).total_seconds()
    except Exception:
        return None

# %%
# ---- Clean driver dataset ----
cleaned_df = final_2023.copy()

# Convert time-like columns to seconds
time_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time']
for col in time_cols:
    cleaned_df[col] = cleaned_df[col].apply(time_to_seconds)

# Drop rows missing LapTime or Compound
before_drop = cleaned_df.shape[0]
cleaned_df = cleaned_df.dropna(subset=['LapTime', 'Compound'])
print(f"🗑️ Dropped {before_drop - cleaned_df.shape[0]} rows with missing LapTime/Compound")

# Handle TyreLife missing
missing_tyre = cleaned_df['TyreLife'].isna().sum()
cleaned_df['TyreLife'] = cleaned_df['TyreLife'].fillna(0).astype(int)
print(f"🛠️ Filled {missing_tyre} missing TyreLife values with 0")

# Handle FreshTyre missing
missing_fresh = cleaned_df['FreshTyre'].isna().sum()
cleaned_df['FreshTyre'] = cleaned_df['FreshTyre'].fillna(False).astype(int)  # 0/1
print(f"🛠️ Filled {missing_fresh} missing FreshTyre values with False")

# Remove outlier laps (1.5x median LapTime)
median_lap = cleaned_df['LapTime'].median()
before_outlier = cleaned_df.shape[0]
cleaned_df = cleaned_df[cleaned_df['LapTime'] < 1.5 * median_lap]
print(f"⚡ Removed {before_outlier - cleaned_df.shape[0]} outlier laps")

# Reset index
cleaned_df = cleaned_df.reset_index(drop=True)

# Save cleaned dataset
cleaned_df.to_csv("driver_data_cleaned.csv", index=False)
print("💾 Saved cleaned dataset → driver_data_cleaned.csv")
# Out:
# 🗑️ Dropped 5350 rows with missing LapTime/Compound
# 🛠️ Filled 0 missing TyreLife values with 0
# 🛠️ Filled 0 missing FreshTyre values with False
# ⚡ Removed 1056 outlier laps
# 💾 Saved cleaned dataset → driver_data_cleaned.csv

# %%
# Out:
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    VER             1        2.0    1.0   MEDIUM         2          1
# 1    VER             1        5.0    2.0   MEDIUM         5          0
# 2    VER             1        7.0    3.0     SOFT         2          1
# 3    VER             1        8.0    3.0     SOFT         3          1
# 4    VER             1       10.0    4.0     SOFT         5          0
#
#    LapTime  Sector1Time  Sector2Time  Sector3Time             Team  Position  \
# 0   95.429       30.535       41.153       23.741  Red Bull Racing       NaN
# 1  113.662       30.271       55.102       28.289  Red Bull Racing       NaN
# 2   93.375       29.507       40.148       23.720  Red Bull Racing       NaN
# 3  128.682       38.151       59.322       31.209  Red Bull Racing       NaN
# 4   97.900       31.366       42.527       24.007  Red Bull Racing       NaN
#
#                    GP SessionType                    Time
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# ---- Normalized dataset ----
norm_df = cleaned_df.copy()
scaler = MinMaxScaler()

num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife']
norm_df[num_cols] = scaler.fit_transform(norm_df[num_cols])

# Save normalized dataset
norm_df.to_csv("driver_data_normalized.csv", index=False)
print(f"💾 Saved normalized dataset → driver_data_normalized.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.preprocessing import MinMaxScaler
#       3 # ---- Normalized dataset ----
# ----> 4 norm_df = cleaned_df.copy()
#       5 scaler = MinMaxScaler()
#       7 num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife']
#
# NameError: name 'cleaned_df' is not defined

# %%
import pandas as pd 
import fastf1
fastf1.Cache.enable_cache('f1_cache')
cleaned_df = pd.read_csv('driver_data_cleaned.csv')
cleaned_df.head()
# Out:
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    VER             1        2.0    1.0   MEDIUM         2          1
# 1    VER             1        5.0    2.0   MEDIUM         5          0
# 2    VER             1        7.0    3.0     SOFT         2          1
# 3    VER             1        8.0    3.0     SOFT         3          1
# 4    VER             1       10.0    4.0     SOFT         5          0
#
#    LapTime  Sector1Time  Sector2Time  Sector3Time             Team  Position  \
# 0   95.429       30.535       41.153       23.741  Red Bull Racing       NaN
# 1  113.662       30.271       55.102       28.289  Red Bull Racing       NaN
# 2   93.375       29.507       40.148       23.720  Red Bull Racing       NaN
# 3  128.682       38.151       59.322       31.209  Red Bull Racing       NaN
# 4   97.900       31.366       42.527       24.007  Red Bull Racing       NaN
#
#                    GP SessionType                    Time
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# ---- Normalized dataset ----
norm_df = cleaned_df.copy()
scaler = MinMaxScaler()

num_cols = ['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'TyreLife']
norm_df[num_cols] = scaler.fit_transform(norm_df[num_cols])

# Save normalized dataset
norm_df.to_csv("driver_data_normalized.csv", index=False)
print(f"💾 Saved normalized dataset → driver_data_normalized.csv")
# Out:
# 💾 Saved normalized dataset → driver_data_normalized.csv

# %%
norm_f1 = pd.read_csv('driver_data_normalized.csv')
norm_f1.head()
# Out:
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    VER             1        2.0    1.0   MEDIUM  0.017544          1
# 1    VER             1        5.0    2.0   MEDIUM  0.070175          0
# 2    VER             1        7.0    3.0     SOFT  0.017544          1
# 3    VER             1        8.0    3.0     SOFT  0.035088          1
# 4    VER             1       10.0    4.0     SOFT  0.070175          0
#
#     LapTime  Sector1Time  Sector2Time  Sector3Time             Team  Position  \
# 0  0.417144     0.231384     0.365870     0.108459  Red Bull Racing       NaN
# 1  0.662191     0.227093     0.580863     0.174097  Red Bull Racing       NaN
# 2  0.389538     0.214675     0.350380     0.108156  Red Bull Racing       NaN
# 3  0.864057     0.355180     0.645906     0.216239  Red Bull Racing       NaN
# 4  0.450353     0.244892     0.387047     0.112298  Red Bull Racing       NaN
#
#                    GP SessionType                    Time
# ...

# %%
import pandas as pd 
import fastf1
fastf1.Cache.enable_cache('f1_cache')
cleaned_df = pd.read_csv('driver_data_cleaned.csv')
cleaned_df.head()
# Out:
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    VER             1        2.0    1.0   MEDIUM         2          1
# 1    VER             1        5.0    2.0   MEDIUM         5          0
# 2    VER             1        7.0    3.0     SOFT         2          1
# 3    VER             1        8.0    3.0     SOFT         3          1
# 4    VER             1       10.0    4.0     SOFT         5          0
#
#    LapTime  Sector1Time  Sector2Time  Sector3Time             Team  Position  \
# 0   95.429       30.535       41.153       23.741  Red Bull Racing       NaN
# 1  113.662       30.271       55.102       28.289  Red Bull Racing       NaN
# 2   93.375       29.507       40.148       23.720  Red Bull Racing       NaN
# 3  128.682       38.151       59.322       31.209  Red Bull Racing       NaN
# 4   97.900       31.366       42.527       24.007  Red Bull Racing       NaN
#
#                    GP SessionType                    Time
# ...

# %%
import pandas as pd 
import fastf1
fastf1.Cache.enable_cache('f1_cache')
cleaned_df = pd.read_csv('driver_data_cleaned.csv')
cleaned_df.head()
# Out:
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    VER             1        2.0    1.0   MEDIUM         2          1
# 1    VER             1        5.0    2.0   MEDIUM         5          0
# 2    VER             1        7.0    3.0     SOFT         2          1
# 3    VER             1        8.0    3.0     SOFT         3          1
# 4    VER             1       10.0    4.0     SOFT         5          0
#
#    LapTime  Sector1Time  Sector2Time  Sector3Time             Team  Position  \
# 0   95.429       30.535       41.153       23.741  Red Bull Racing       NaN
# 1  113.662       30.271       55.102       28.289  Red Bull Racing       NaN
# 2   93.375       29.507       40.148       23.720  Red Bull Racing       NaN
# 3  128.682       38.151       59.322       31.209  Red Bull Racing       NaN
# 4   97.900       31.366       42.527       24.007  Red Bull Racing       NaN
#
#                    GP SessionType                    Time
# ...

# %%
import fastf1
import pandas as pd

# Enable cache (to avoid re-downloading)
fastf1.Cache.enable_cache("f1_cache")

year = 2023
sessions = ["FP1", "FP2", "FP3", "Q", "R", "S"]  # Include Sprint too
weather_records = []

for round_number in range(1, 23):  # 22 races in 2023
    for sess in sessions:
        try:
            session = fastf1.get_session(year, round_number, sess)
            session.load()

            # Weather snapshots (~ every 1 min)
            weather = session.laps.get_weather_data().copy()

            # Add contextual metadata
            weather["GP"] = session.event["EventName"]
            weather["Year"] = year
            weather["SessionType"] = sess
            weather["RoundNumber"] = round_number
            weather["SessionStart"] = session.session_start_time
            weather["SessionEnd"] = session.session_end_time

            weather_records.append(weather)

            print(f"✅ Collected weather for {session.event['EventName']} - {sess}")

        except Exception as e:
            print(f"⚠️ Skipped round {round_number} {sess}: {e}")

# Merge all sessions
weather_df = pd.concat(weather_records, ignore_index=True)

# Sort chronologically: by round number, then session type order
session_order = {"FP1": 1, "FP2": 2, "FP3": 3, "S": 4, "Q": 5, "R": 6}
weather_df["SessionOrder"] = weather_df["SessionType"].map(session_order)

weather_df = weather_df.sort_values(
    by=["RoundNumber", "SessionOrder", "Time"]
).reset_index(drop=True)

# Save to CSV
weather_df.to_csv("weather_2023.csv", index=False)
print(f"💾 Saved → weather_2023.csv ({weather_df.shape[0]} rows)")
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 1 [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '4', '10', '11', '14', '16', '18', '20', '21', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 2 [v3.6.0]
# ...

# %%
import fastf1
import pandas as pd
from tqdm import tqdm

fastf1.Cache.enable_cache("f1_cache")  # use your cache folder

def collect_weather(year=2023):
    all_weather = []

    schedule = fastf1.get_event_schedule(year, include_testing=False)
    for rnd, row in schedule.iterrows():
        event = fastf1.get_event(year, rnd)
        sessions = ["FP1", "FP2", "FP3", "Q", "R"]

        for s in sessions:
            try:
                session = event.get_session(s)
                session.load()

                wd = session.weather_data.copy()
                wd["RoundNumber"] = rnd
                wd["EventName"] = event.EventName
                wd["Session"] = s
                wd["Date"] = event.EventDate

                all_weather.append(wd)

            except Exception as e:
                print(f"⚠️ Skipped round {rnd} {s}: {e}")

    df_weather = pd.concat(all_weather, ignore_index=True)
    df_weather.sort_values(["RoundNumber", "Session", "Time"], inplace=True)
    df_weather.to_csv(f"weather_{year}.csv", index=False)
    print(f"💾 Saved weather data → weather_{year}.csv")

    return df_weather


# Run once
weather_2023 = collect_weather(2023)
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 1 [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '4', '10', '11', '14', '16', '18', '20', '21', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 2 [v3.6.0]
# ...

# %%
import pandas as pd 
import fastf1
fastf1.Cache.enable_cache('f1_cache')
cleaned_df = pd.read_csv('driver_data_cleaned.csv')
cleaned_df.head()
# Out:
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    VER             1        2.0    1.0   MEDIUM         2          1
# 1    VER             1        5.0    2.0   MEDIUM         5          0
# 2    VER             1        7.0    3.0     SOFT         2          1
# 3    VER             1        8.0    3.0     SOFT         3          1
# 4    VER             1       10.0    4.0     SOFT         5          0
#
#    LapTime  Sector1Time  Sector2Time  Sector3Time             Team  Position  \
# 0   95.429       30.535       41.153       23.741  Red Bull Racing       NaN
# 1  113.662       30.271       55.102       28.289  Red Bull Racing       NaN
# 2   93.375       29.507       40.148       23.720  Red Bull Racing       NaN
# 3  128.682       38.151       59.322       31.209  Red Bull Racing       NaN
# 4   97.900       31.366       42.527       24.007  Red Bull Racing       NaN
#
#                    GP SessionType                    Time
# ...

# %%
import fastf1
import pandas as pd
from tqdm import tqdm

fastf1.Cache.enable_cache("f1_cache")  # change folder if needed

def collect_weather(year=2023):
    all_weather = []

    schedule = fastf1.get_event_schedule(year, include_testing=False)
    sessions = ["FP1", "FP2", "FP3", "Q", "R"]

    # total iterations = number of races × number of sessions
    with tqdm(total=len(schedule) * len(sessions), desc=f"Collecting {year} weather") as pbar:
        for rnd, row in schedule.iterrows():
            event = fastf1.get_event(year, rnd)
            for s in sessions:
                try:
                    session = event.get_session(s)
                    session.load()

                    wd = session.weather_data.copy()
                    wd["RoundNumber"] = rnd
                    wd["EventName"] = event.EventName
                    wd["Session"] = s
                    wd["Date"] = event.EventDate

                    all_weather.append(wd)

                except Exception as e:
                    print(f"⚠️ Skipped round {rnd} {s}: {e}")
                finally:
                    pbar.update(1)   # always tick, success or fail

    df_weather = pd.concat(all_weather, ignore_index=True)
    df_weather.sort_values(["RoundNumber", "Session", "Time"], inplace=True)
    df_weather.to_csv(f"weather_{year}.csv", index=False)
    print(f"💾 Saved weather data → weather_{year}.csv")

    return df_weather


# Run once
weather_2023 = collect_weather(2023)
# Out:
# ...
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '4', '10', '11', '14', '16', '18', '20', '21', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
# ...
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# ...

# %%
weather_2023 = pd.read_csv('weather_2023.csv')
weather_2023.head()
# Out:
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0  0 days 00:00:33.860000     27.5      11.0    1017.4     False       42.7
# 1  0 days 00:01:33.859000     27.5      11.0    1017.2     False       42.6
# 2  0 days 00:02:33.873000     27.6      12.0    1017.4     False       42.6
# 3  0 days 00:03:33.888000     27.6      12.0    1017.2     False       42.4
# 4  0 days 00:04:33.887000     27.6      12.0    1017.4     False       42.4
#
#    WindDirection  WindSpeed  RoundNumber           EventName Session  \
# 0            336        3.2            1  Bahrain Grand Prix     FP1
# 1            345        2.7            1  Bahrain Grand Prix     FP1
# 2            340        2.7            1  Bahrain Grand Prix     FP1
# 3            342        2.7            1  Bahrain Grand Prix     FP1
# 4            341        3.4            1  Bahrain Grand Prix     FP1
#
#          Date
# 0  2023-03-05
# 1  2023-03-05
# 2  2023-03-05
# 3  2023-03-05
# 4  2023-03-05

# %%
weather_2023.columns
# Out:
# Index(['Time', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp',
#        'WindDirection', 'WindSpeed', 'RoundNumber', 'EventName', 'Session',
#        'Date'],
#       dtype='object')

# %%
weather_2023['EventName'].unique()
# Out:
# array(['Bahrain Grand Prix', 'Saudi Arabian Grand Prix',
#        'Australian Grand Prix', 'Azerbaijan Grand Prix',
#        'Miami Grand Prix', 'Monaco Grand Prix', 'Spanish Grand Prix',
#        'Canadian Grand Prix', 'Austrian Grand Prix', 'British Grand Prix',
#        'Hungarian Grand Prix', 'Belgian Grand Prix', 'Dutch Grand Prix',
#        'Italian Grand Prix', 'Singapore Grand Prix',
#        'Japanese Grand Prix', 'Qatar Grand Prix',
#        'United States Grand Prix', 'Mexico City Grand Prix',
#        'São Paulo Grand Prix', 'Las Vegas Grand Prix',
#        'Abu Dhabi Grand Prix'], dtype=object)

# %%
weather_2023['EventName'].value_counts()
# Out:
# EventName
# Hungarian Grand Prix        554
# Dutch Grand Prix            553
# Australian Grand Prix       545
# Singapore Grand Prix        533
# Bahrain Grand Prix          511
# Mexico City Grand Prix      511
# Canadian Grand Prix         498
# Japanese Grand Prix         491
# Monaco Grand Prix           488
# Spanish Grand Prix          488
# British Grand Prix          488
# Miami Grand Prix            487
# Italian Grand Prix          481
# Abu Dhabi Grand Prix        478
# Saudi Arabian Grand Prix    475
# Las Vegas Grand Prix        439
# Azerbaijan Grand Prix       349
# São Paulo Grand Prix        349
# Belgian Grand Prix          333
# United States Grand Prix    329
# Qatar Grand Prix            324
# Austrian Grand Prix         322
# Name: count, dtype: int64

# %%
# Code to clean and normalise the Weather data (2023)
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

def process_weather(file_in, file_cleaned, file_normalized):
    # Load raw weather data
    raw_weather = pd.read_csv(file_in)

    # ---- Cleaned Weather Data ----
    weather_df = raw_weather.copy()

    # Drop duplicate rows
    weather_df = weather_df.drop_duplicates()

    # Forward fill NaN values
    weather_df = weather_df.fillna(method='ffill')

    # Ensure numeric datatypes
    num_cols = ['AirTemp', 'Humidity', 'Pressure', 'TrackTemp', 'WindDirection', 'WindSpeed']
    weather_df[num_cols] = weather_df[num_cols].astype(float)

    # Save cleaned dataset (with metadata intact)
    weather_df.to_csv(file_cleaned, index=False)
    print(f"💾 Saved cleaned weather data → {file_cleaned}")

    # ---- Normalized Weather Data ----
    norm_weather = weather_df.copy()

    scaler = MinMaxScaler()
    norm_weather[num_cols] = scaler.fit_transform(norm_weather[num_cols])

    # Keep Rainfall as is (binary)
    # Drop metadata for ML
    drop_cols = ['RoundNumber', 'EventName', 'Session', 'Date']
    norm_weather = norm_weather.drop(columns=drop_cols)

    # Save normalized dataset
    norm_weather.to_csv(file_normalized, index=False)
    print(f"💾 Saved normalized weather data → {file_normalized}")


# Example usage
process_weather(
    file_in="weather_2023.csv",
    file_cleaned="weather_2023_cleaned.csv",
    file_normalized="weather_2023_normalized.csv"
)
# Out:
# 💾 Saved cleaned weather data → weather_2023_cleaned.csv
# 💾 Saved normalized weather data → weather_2023_normalized.csv

# %%
clean_weather_2023 = pd.read_csv('weather_2023_cleaned.csv')
clean_weather_2023.head()
# Out:
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0  0 days 00:00:33.860000     27.5      11.0    1017.4     False       42.7
# 1  0 days 00:01:33.859000     27.5      11.0    1017.2     False       42.6
# 2  0 days 00:02:33.873000     27.6      12.0    1017.4     False       42.6
# 3  0 days 00:03:33.888000     27.6      12.0    1017.2     False       42.4
# 4  0 days 00:04:33.887000     27.6      12.0    1017.4     False       42.4
#
#    WindDirection  WindSpeed  RoundNumber           EventName Session  \
# 0          336.0        3.2            1  Bahrain Grand Prix     FP1
# 1          345.0        2.7            1  Bahrain Grand Prix     FP1
# 2          340.0        2.7            1  Bahrain Grand Prix     FP1
# 3          342.0        2.7            1  Bahrain Grand Prix     FP1
# 4          341.0        3.4            1  Bahrain Grand Prix     FP1
#
#          Date
# 0  2023-03-05
# 1  2023-03-05
# 2  2023-03-05
# 3  2023-03-05
# 4  2023-03-05

# %%
norm_weather_2023 = pd.read_csv('weather_2023_normalized.csv')
norm_weather_2023.head()
# Out:
#                      Time   AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0  0 days 00:00:33.860000  0.637168  0.000000  0.990464     False   0.813333
# 1  0 days 00:01:33.859000  0.637168  0.000000  0.989635     False   0.811429
# 2  0 days 00:02:33.873000  0.641593  0.011905  0.990464     False   0.811429
# 3  0 days 00:03:33.888000  0.641593  0.011905  0.989635     False   0.807619
# 4  0 days 00:04:33.887000  0.641593  0.011905  0.990464     False   0.807619
#
#    WindDirection  WindSpeed
# 0       0.933333   0.421053
# 1       0.958333   0.355263
# 2       0.944444   0.355263
# 3       0.950000   0.355263
# 4       0.947222   0.447368

# %%
import pandas as pd 
import fastf1
fastf1.Cache.enable_cache('f1_cache')
cleaned_df = pd.read_csv('driver_data_cleaned.csv')
cleaned_df.head()
# Out:
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    VER             1        2.0    1.0   MEDIUM         2          1
# 1    VER             1        5.0    2.0   MEDIUM         5          0
# 2    VER             1        7.0    3.0     SOFT         2          1
# 3    VER             1        8.0    3.0     SOFT         3          1
# 4    VER             1       10.0    4.0     SOFT         5          0
#
#    LapTime  Sector1Time  Sector2Time  Sector3Time             Team  Position  \
# 0   95.429       30.535       41.153       23.741  Red Bull Racing       NaN
# 1  113.662       30.271       55.102       28.289  Red Bull Racing       NaN
# 2   93.375       29.507       40.148       23.720  Red Bull Racing       NaN
# 3  128.682       38.151       59.322       31.209  Red Bull Racing       NaN
# 4   97.900       31.366       42.527       24.007  Red Bull Racing       NaN
#
#                    GP SessionType                    Time
# ...

# %%
import fastf1
import pandas as pd

YEAR = 2023

schedule = fastf1.get_event_schedule(YEAR)

all_trackstatus_laps = []

for _, event in schedule.iterrows():

    gp = event["EventName"]

    try:

        print(f"Loading {gp}...")

        session = fastf1.get_session(
            YEAR,
            gp,
            "R"
        )

        session.load()

        laps = session.laps.copy()

        track_df = laps[
            [
                "Driver",
                "LapNumber",
                "TrackStatus"
            ]
        ].copy()

        track_df["GP"] = gp
        track_df["Year"] = YEAR

        all_trackstatus_laps.append(
            track_df
        )

    except Exception as e:

        print(f"Failed: {gp}")
        print(e)

trackstatus_2023 = pd.concat(
    all_trackstatus_laps,
    ignore_index=True
)

print(trackstatus_2023.shape)

print(
    trackstatus_2023.head()
)

trackstatus_2023.to_csv(
    "trackstatus_laps_2023.csv",
    index=False
)

print(
    "Saved trackstatus_laps_2023.csv"
)
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (4.22 GB) C:\Users\VANSH\AppData\Local\Temp\fastf1
# events      WARNING 	Correcting user input 'Pre-Season Testing' to 'British Grand Prix'
# core           INFO 	Loading data for British Grand Prix - Race [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Loading Pre-Season Testing...
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# ...

# %%
trackstatus_2023 = pd.read_csv(
    "trackstatus_laps_2023.csv"
)
final_merged_2023 = pd.read_csv("C:/Users/VANSH/Formula1/datasets/2023/final_merged_2023_data.csv")

merged_2023 = final_merged_2023.merge(
    trackstatus_2023,
    on=["GP", "Driver", "LapNumber"],
    how="left"
)

print(merged_2023.shape)
print(merged_2023["TrackStatus"].isna().sum())
print(merged_2023.head())
merged_2023.to_csv("C:/Users/VANSH/Formula1/datasets/2023/final_merged_2023_data_with_trackstatus.csv", index=False)
# Out:
# C:\Users\VANSH\AppData\Local\Temp\ipykernel_31328\2205054687.py:4: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   final_merged_2023 = pd.read_csv("C:/Users/VANSH/Formula1/datasets/2023/final_merged_2023_data.csv")
# (39877, 28)
# 1463
#   Driver  DriverNumber  LapNumber  Stint Compound  TyreLife  FreshTyre  \
# 0    ALB            23          3      2   MEDIUM         3          0
# 1    ALB            23          4      2   MEDIUM         4          0
# 2    ALB            23          5      2   MEDIUM         5          0
# 3    ALB            23          6      2   MEDIUM         6          0
# 4    ALB            23          8      3   MEDIUM         8          0
#
#    LapTime  Sector1Time  Sector2Time  ...  Rainfall TrackTemp  WindDirection  \
# 0   96.216       30.470       41.812  ...     False      41.1           10.0
# 1  137.050       42.034       63.859  ...     False      41.1          341.0
# ...
